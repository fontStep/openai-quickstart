# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_string = """
<!DOCTYPE html>
<html>
<body>
    <div>
        <h1>Foo</h1>
        <p>Some intro text about Foo.</p>
        <div>
            <h2>Bar main section</h2>
            <p>Some intro text about Bar.</p>
            <h3>Bar subsection 1</h3>
            <p>Some text about the first subtopic of Bar.</p>
            <h3>Bar subsection 2</h3>
            <p>Some text about the second subtopic of Bar.</p>
        </div>
        <div>
            <h2>Baz</h2>
            <p>Some text about Baz</p>
        </div>
        <br>
        <p>Some concluding text about Foo</p>
    </div>
</body>
</html>
"""

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits = html_splitter.split_text(html_string)
contents =[html_header.page_content for  html_header in html_header_splits]

print(contents)
# Out:
# ['Foo', 'Some intro text about Foo.  \nBar main section Bar subsection 1 Bar subsection 2', 'Some intro text about Bar.', 'Some text about the first subtopic of Bar.', 'Some text about the second subtopic of Bar.', 'Baz', 'Some text about Baz', 'Some concluding text about Foo']

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

url = "https://plato.stanford.edu/entries/goedel/"

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

# for local file use html_splitter.split_text_from_file(<path_to_file>)
html_header_splits = html_splitter.split_text_from_url(url)

chunk_size = 500
chunk_overlap = 30
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size, chunk_overlap=chunk_overlap
)

# Split
splits = text_splitter.split_documents(html_header_splits)
splits[80:85]
# Out:
# [Document(page_content='We see that Gödel first tried to reduce the consistency problem for analysis to that of arithmetic. This seemed to require a truth definition for arithmetic, which in turn led to paradoxes, such as the Liar paradox (“This sentence is false”) and Berry’s paradox (“The least number not defined by an expression consisting of just fourteen English words”). Gödel then noticed that such paradoxes would not necessarily arise if truth were replaced by provability. But this means that arithmetic truth', metadata={'Header 1': 'Kurt Gödel', 'Header 2': '2. Gödel’s Mathematical Work', 'Header 3': '2.2 The Incompleteness Theorems', 'Header 4': '2.2.1 The First Incompleteness Theorem'}),
#  Document(page_content='means that arithmetic truth and arithmetic provability are not co-extensive — whence the First Incompleteness Theorem.', metadata={'Header 1': 'Kurt Gödel', 'Header 2': '2. Gödel’s Mathematical Work', 'Header 3': '2.2 The Incompleteness Theorems', 'Header 4': '2.2.1 The First Incompleteness Theorem'}),
#  Document(page_content='This account of Gödel’s discovery was told to Hao Wang very much after the fact; but in Gödel’s contemporary correspondence with Bernays and Zermelo, essentially the same description of his path to the theorems is given. (See Gödel 2003a and Gödel 2003b respectively.) From those accounts we see that the undefinability of truth in arithmetic, a result credited to Tarski, was likely obtained in some form by Gödel by 1931. But he neither publicized nor published the result; the biases logicians', metadata={'Header 1': 'Kurt Gödel', 'Header 2': '2. Gödel’s Mathematical Work', 'Header 3': '2.2 The Incompleteness Theorems', 'Header 4': '2.2.1 The First Incompleteness Theorem'}),
#  Document(page_content='result; the biases logicians had expressed at the time concerning the notion of truth, biases which came vehemently to the fore when Tarski announced his results on the undefinability of truth in formal systems 1935, may have served as a deterrent to Gödel’s publication of that theorem.', metadata={'Header 1': 'Kurt Gödel', 'Header 2': '2. Gödel’s Mathematical Work', 'Header 3': '2.2 The Incompleteness Theorems', 'Header 4': '2.2.1 The First Incompleteness Theorem'}),
#  Document(page_content='We now describe the proof of the two theorems, formulating Gödel’s results in Peano arithmetic. Gödel himself used a system related to that defined in Principia Mathematica, but containing Peano arithmetic. In our presentation of the First and Second Incompleteness Theorems we refer to Peano arithmetic as P, following Gödel’s notation.', metadata={'Header 1': 'Kurt Gödel', 'Header 2': '2. Gödel’s Mathematical Work', 'Header 3': '2.2 The Incompleteness Theorems', 'Header 4': '2.2.2 The proof of the First Incompleteness Theorem'})]

# %%
url = "https://www.cnn.com/2023/09/25/weather/el-nino-winter-us-climate/index.html"

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits = html_splitter.split_text_from_url(url)
print(html_header_splits[1].page_content[:500])
# Out:
# No two El Niño winters are the same, but many have temperature and precipitation trends in common.
# Average conditions during an El Niño winter across the continental US.
# One of the major reasons is the position of the jet stream, which often shifts south during an El Niño winter. This shift typically brings wetter and cooler weather to the South while the North becomes drier and warmer, according to NOAA.
# Because the jet stream is essentially a river of air that storms flow through, they c

# %%
# 加载待分割长文本
with open('../tests/state_of_the_union.txt',encoding='utf-8') as f:
    state_of_the_union = f.read()

# %%
state_of_the_union
# Out:
# 'Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland. \n\nIn this struggle as President Zelenskyy said in his speech to the European Parliament “Light will win over darkness.” The Ukrainian Ambassador to the United States is here tonight. \n\nLet each of us here tonight in this Chamber send an unmistakable signal to Ukraine and to the world. \n\nPlease rise if you are able and show that, Yes, we the United States of America stand with the Ukrainian people. \n\nThroughout our history we’ve learned this lesson when dictators do not pay a price for their aggression they cause more chaos.   \n\nThey keep moving.   \n\nAnd the costs and the threats to America and the world keep rising.   \n\nThat’s why the NATO Alliance was created to secure peace and stability in Europe after World War 2. \n\nThe United States is a member along with 29 other nations. \n\nIt matters. American diplomacy matters. American resolve matters. \n\nPutin’s latest attack on Ukraine was premeditated and unprovoked. \n\nHe rejected repeated efforts at diplomacy. \n\nHe thought the West and NATO wouldn’t respond. And he thought he could divide us at home. Putin was wrong. We were ready.  Here is what we did.   \n\nWe prepared extensively and carefully. \n\nWe spent months building a coalition of other freedom-loving nations from Europe and the Americas to Asia and Africa to confront Putin. \n\nI spent countless hours unifying our European allies. We shared with the world in advance what we knew Putin was planning and precisely how he would try to falsely justify his aggression.  \n\nWe countered Russia’s lies with truth.   \n\nAnd now that he has acted the free world is holding him accountable. \n\nAlong with twenty-seven members of the European Union including France, Germany, Italy, as well as countries like the United Kingdom, Canada, Japan, Korea, Australia, New Zealand, and many others, even Switzerland. \n\nWe are inflicting pain on Russia and supporting the people of Ukraine. Putin is now isolated from the world more than ever. \n\nTogether with our allies –we are right now enforcing powerful economic sanctions. \n\nWe are cutting off Russia’s largest banks from the international financial system.  \n\nPreventing Russia’s central bank from defending the Russian Ruble making Putin’s $630 Billion “war fund” worthless.   \n\nWe are choking off Russia’s access to technology that will sap its economic strength and weaken its military for years to come.  \n\nTonight I say to the Russian oligarchs and corrupt leaders who have bilked billions of dollars off this violent regime no more. \n\nThe U.S. Department of Justice is assembling a dedicated task force to go after the crimes of Russian oligarchs.  \n\nWe are joining with our European allies to find and seize your yachts your luxury apartments your private jets. We are coming for your ill-begotten gains. \n\nAnd tonight I am announcing that we will join our allies in closing off Ame ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap  = 20,
    length_function = len,
    add_start_index = True,
)

# %%
docs = text_splitter.create_documents([state_of_the_union])

docs
# Out:
# [Document(page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and', metadata={'start_index': 0}),
#  Document(page_content='of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.', metadata={'start_index': 82}),
#  Document(page_content='Last year COVID-19 kept us apart. This year we are finally together again.', metadata={'start_index': 166}),
#  Document(page_content='Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.', metadata={'start_index': 243}),
#  Document(page_content='With a duty to one another to the American people to the Constitution.', metadata={'start_index': 340}),
#  Document(page_content='And with an unwavering resolve that freedom will always triumph over tyranny.', metadata={'start_index': 413}),
#  Document(page_content='Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he', metadata={'start_index': 493}),
#  Document(page_content='world thinking he could make it bend to his menacing ways. But he badly miscalculated.', metadata={'start_index': 575}),
#  Document(page_content='He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of', metadata={'start_index': 664}),
#  Document(page_content='he met a wall of strength he never imagined.', metadata={'start_index': 741}),
#  Document(page_content='He met the Ukrainian people.', metadata={'start_index': 788}),
#  Document(page_content='From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their', metadata={'start_index': 819}),
#  Document(page_content='courage, their determination, inspires the world.', metadata={'start_index': 890}),
#  Document(page_content='Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers', metadata={'start_index': 942}),
#  Document(page_content='retirees teachers turned soldiers defending their homeland.', metadata={'start_index': 1021}),
#  Document(page_content='In this struggle as President Zelenskyy said in his speech to the European Parliament “Light will', metadata={'start_index': 1083}),
#  Document(page_content='“Light will win over darkness.” The Ukrainian Ambassador to the United States is here tonight.', metadata={'start_index': 1169}),
#  Document(page_content='Let each of us here tonight in this Chamber send an unmistakable signal to Ukraine and to the', metadata={'start_index': 1266}),
#  Document(page_content='Ukraine and to the world.', metadata={'start_index': 1341}),
#  Document(page_content='Please rise if you are able and show that, Yes, we the United States of America stand with the', metadata={'start_index': 1369}),
#  Document(page_content='stand with the Ukrainian people.', metadata={'start_index': 1449}),
#  Document(page_content='Throughout our history we’ve learned this lesson when dictators do not pay a price for their', metadata={'start_index': 1484}),
#  Document(page_content='a price for their aggression they cause more chaos.', metadata={'start_index': 1559}),
#  Document(page_content='They keep moving.   \n\nAnd the costs and the threats to America and the world keep rising.', metadata={'start_index': 1615}),
#  Document(page_content='That’s why the NATO Alliance was created to secure peace and stability in Europe after World War 2.', metadata={'start_index': 1709}),
#  Document(page_content='after World War 2.', metadata={'start_index': 1790}),
#  Document(page_content='The United States is a member along with 29 other nations.', metadata={'start_index': 1811}),
#  Document(page_content='It matters. American diplomacy matters. American resolve matters.', metadata={'start_index': 1872}),
#  Document(page_content='Putin’s latest attack on Ukraine was premeditated and unprovoked.', metadata={'start_index': 1940}),
#  Document(page_content='He rejected repeated efforts at diplomacy.', metadata={'start_index': 2008}),
#  Document(page_content='He thought the West and NATO wouldn’t respond. And he thought he could divide us at home. Putin was', metadata={'start_index': 2053}),
#  Document(page_content='at home. Putin was wrong. We were ready.  Here is what we did.', metadata={'start_index': 2134}),
#  Document(page_content='We prepared extensively and carefully.', metadata={'start_index': 2201}),
#  Document(page_content='We spent months building a coalition of other freedom-loving nations from Europe and the Americas', metadata={'start_index': 2242}),
#  Document(page_content='and the Americas to Asia and Africa to confront Putin.', metadata={'start_index': 2323}),
#  Document(page_content='I spent countless hours unifying our European allies. We shared with the world in advance what we', metadata={'start_index': 2380}),
#  Document(page_content='in advance what we knew Putin was planning and precisely how he would try to falsely justify his', metadata={'start_index': 2459}),
#  Document(page_content='falsely justify his aggression.', metadata={'start_index': 2536}),
#  Document(page_content='We countered Russia’s lies with truth.', metadata={'start_index': 2571}),
#  Document(page_content='And now that he has acted the free world is holding him accountable.', metadata={'start_index': 2614}),
#  Document(page_content='Along with twenty-seven members of the European Union including France, Germany, Italy, as well as', metadata={'start_index': 2685}),
#  Document(page_content='Italy, as well as countries like the United Kingdom, Canada, Japan, Korea, Australia, New Zealand,', metadata={'start_index': 2766}),
#  Document(page_content='New Zealand, and many others, even Switzerland.', metadata={'start_index': 2852}),
#  Document(page_content='We are inflicting pain on Russia and supporting the people of Ukraine. Putin is now isolated from', metadata={'start_index': 2902}),
#  Document(page_content='now isolated from the world more than ever.', metadata={'start_index': 2982}),
#  Document(page_content='Together with our allies –we are right now enforcing powerful economic sanctions.', metadata={'start_index': 3028}),
#  Document(page_content='We are cutting off Russia’s largest banks from the international financial system.', metadata={'start_index': 3112}),
#  Document(page_content='Preventing Russia’s central bank from defending the Russian Ruble making Putin’s $630 Billion “war', metadata={'start_index': 3198}),
#  Document(page_content='$630 Billion “war fund” worthless.', metadata={'start_index': 3279}),
#  Document(page_content='We are choking off Russia’s access to technology that will sap its economic strength and weaken its', metadata={'start_index': 3318}),
#  Document(page_content='and weaken its military for years to come.', metadata={'start_index': 3403}),
#  Document(page_content='Tonight I say to the Russian oligarchs and corrupt leaders who have bilked billions of dollars off', metadata={'start_index': 3449}),
#  Document(page_content='of dollars off this violent regime no more.', metadata={'start_index': 3533}),
#  Document(page_content='The U.S. Department of Justice is assembling a dedicated task force to go after the crimes of', metadata={'start_index': 3579}),
#  Document(page_content='after the crimes of Russian oligarchs.', metadata={'start_index': 3653}),
#  Document(page_content='We are joining with our European allies to find and seize your yachts your luxury apartments your', metadata={'start_index': 3695}),
#  Document(page_content='apartments your private jets. We are coming for your ill-begotten gains.', metadata={'start_index': 3777}),
#  Document(page_content='And tonight I am announcing that we will join our allies in closing off American air space to all', metadata={'start_index': 3852}),
#  Document(page_content='air space to all Russian flights – further isolating Russia – and adding an additional squeeze –on', metadata={'start_index': 3933}),
#  Document(page_content='squeeze –on their economy. The Ruble has lost 30% of its value.', metadata={'start_index': 4020}),
#  Document(page_content='The Russian stock market has lost 40% of its value and trading remains suspended. Russia’s economy', metadata={'start_index': 4086}),
#  Document(page_content='Russia’s economy is reeling and Putin alone is to blame.', metadata={'start_index': 4168}),
#  Document(page_content='Together with our allies we are providing support to the Ukrainians in their fight for freedom.', metadata={'start_index': 4227}),
#  Document(page_content='fight for freedom. Military assistance. Economic assistance. Humanitarian assistance.', metadata={'start_index': 4304}),
#  Document(page_content='We are giving more than $1 Billion in direct assistance to Ukraine.', metadata={'start_index': 4392}),
#  Document(page_content='And we will continue to aid the Ukrainian people as they defend their country and to help ease', metadata={'start_index': 4462}),
#  Document(page_content='and to help ease their suffering.', metadata={'start_index': 4540}),
#  Document(page_content='Let me be clear, our forces are not engaged and will not engage in conflict with Russian forces in', metadata={'start_index': 4577}),
#  Document(page_content='Russian forces in Ukraine.', metadata={'start_index': 4658}),
#  Document(page_content='Our forces are not going to Europe to fight in Ukraine, but to defend our NATO Allies – in the', metadata={'start_index': 4688}),
#  Document(page_content='Allies – in the event that Putin decides to keep moving west.', metadata={'start_index': 4767}),
#  Document(page_content='For that purpose we’ve mobilized American ground forces, air squadrons, and ship deployments to', metadata={'start_index': 4832}),
#  Document(page_content='ship deployments to protect NATO countries including Poland, Romania, Latvia, Lithuania, and', metadata={'start_index': 4908}),
#  Document(page_content='Lithuania, and Estonia.', metadata={'start_index': 4986}),
#  Document(page_content='As I have made crystal clear the United States and our Allies will defend every inch of territory', metadata={'start_index': 5012}),
#  Document(page_content='inch of territory of NATO countries with the full force of our collective power.', metadata={'start_index': 5092}),
#  Document(page_content='And we remain clear-eyed. The Ukrainians are fighting back with pure courage. But the next few days', metadata={'start_index': 5176}),
#  Document(page_content='the next few days weeks, months, will be hard on them.', metadata={'start_index': 5258}),
#  Document(page_content='Putin has unleashed violence and chaos.  But while he may make gains on the battlefield – he will', metadata={'start_index': 5316}),
#  Document(page_content='– he will pay a continuing high price over the long run.', metadata={'start_index': 5404}),
#  Document(page_content='And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that', metadata={'start_index': 5463}),
#  Document(page_content='shown that they will not tolerate anyone who tries to take their country backwards.', metadata={'start_index': 5551}),
#  Document(page_content='To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading', metadata={'start_index': 5638}),
#  Document(page_content='dictator, invading a foreign country, has costs around the world.', metadata={'start_index': 5718}),
#  Document(page_content='And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s', metadata={'start_index': 5786}),
#  Document(page_content='at Russia’s economy. And I will use every tool at our disposal to protect American businesses and', metadata={'start_index': 5867}),
#  Document(page_content='businesses and consumers.', metadata={'start_index': 5950}),
#  Document(page_content='Tonight, I can announce that the United States has worked with 30 other countries to release 60', metadata={'start_index': 5978}),
#  Document(page_content='to release 60 Million barrels of oil from reserves around the world.', metadata={'start_index': 6060}),
#  Document(page_content='America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum', metadata={'start_index': 6132}),
#  Document(page_content='Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.', metadata={'start_index': 6205}),
#  Document(page_content='These steps will help blunt gas prices here at home. And I know the news about what’s happening can', metadata={'start_index': 6306}),
#  Document(page_content='happening can seem alarming.', metadata={'start_index': 6392}),
#  Document(page_content='But I want you to know that we are going to be okay.', metadata={'start_index': 6423}),
#  Document(page_content='When the history of this era is written Putin’s war on Ukraine will have left Russia weaker and the', metadata={'start_index': 6478}),
#  Document(page_content='weaker and the rest of the world stronger.', metadata={'start_index': 6563}),
#  Document(page_content='While it shouldn’t have taken something so terrible for people around the world to see what’s at', metadata={'start_index': 6608}),
#  Document(page_content='to see what’s at stake now everyone sees it clearly.', metadata={'start_index': 6688}),
#  Document(page_content='We see the unity among leaders of nations and a more unified Europe a more unified West. And we see', metadata={'start_index': 6743}),
#  Document(page_content='West. And we see unity among the people who are gathering in cities in large crowds around the', metadata={'start_index': 6826}),
#  Document(page_content='crowds around the world even in Russia to demonstrate their support for Ukraine.', metadata={'start_index': 6903}),
#  Document(page_content='In the battle between democracy and autocracy, democracies are rising to the moment, and the world', metadata={'start_index': 6987}),
#  Document(page_content='and the world is clearly choosing the side of peace and security.', metadata={'start_index': 7072}),
#  Document(page_content='This is a real test. It’s going to take time. So let us continue to draw inspiration from the iron', metadata={'start_index': 7140}),
#  Document(page_content='from the iron will of the Ukrainian people.', metadata={'start_index': 7225}),
#  Document(page_content='To our fellow Ukrainian Americans who forge a deep bond that connects our two nations we stand with', metadata={'start_index': 7271}),
#  Document(page_content='we stand with you.', metadata={'start_index': 7357}),
#  Document(page_content='Putin may circle Kyiv with tanks, but he will never gain the hearts and souls of the Ukrainian', metadata={'start_index': 7378}),
#  Document(page_content='of the Ukrainian people.', metadata={'start_index': 7456}),
#  Document(page_content='He will never extinguish their love of freedom. He will never weaken the resolve of the free world.', metadata={'start_index': 7483}),
#  Document(page_content='of the free world.', metadata={'start_index': 7564}),
#  Document(page_content='We meet tonight in an America that has lived through two of the hardest years this nation has ever', metadata={'start_index': 7585}),
#  Document(page_content='nation has ever faced.', metadata={'start_index': 7668}),
#  Document(page_content='The pandemic has been punishing.', metadata={'start_index': 7693}),
#  Document(page_content='And so many families are living paycheck to paycheck, struggling to keep up with the rising cost of', metadata={'start_index': 7728}),
#  Document(page_content='the rising cost of food, gas, housing, and so much more.', metadata={'start_index': 7809}),
#  Document(page_content='I understand.', metadata={'start_index': 7868}),
#  Document(page_content='I remember when my Dad had to leave our home in Scranton, Pennsylvania to find work. I grew up in a', metadata={'start_index': 7884}),
#  Document(page_content='I grew up in a family where if the price of food went up, you felt it.', metadata={'start_index': 7969}),
#  Document(page_content='That’s why one of the first things I did as President was fight to pass the American Rescue Plan.', metadata={'start_index': 8042}),
#  Document(page_content='Because people were hurting. We needed to act, and we did.', metadata={'start_index': 8143}),
#  Document(page_content='Few pieces of legislation have done more in a critical moment in our history to lift us out of', metadata={'start_index': 8204}),
#  Document(page_content='to lift us out of crisis.', metadata={'start_index': 8281}),
#  Document(page_content='It fueled our efforts to vaccinate the nation and combat COVID-19. It delivered immediate economic', metadata={'start_index': 8309}),
#  Document(page_content='immediate economic relief for tens of millions of Americans.', metadata={'start_index': 8389}),
#  Document(page_content='Helped put food on their table, keep a roof over their heads, and cut the cost of health insurance.', metadata={'start_index': 8453}),
#  Document(page_content='health insurance.', metadata={'start_index': 8535}),
#  Document(page_content='And as my Dad used to say, it gave people a little breathing room.', metadata={'start_index': 8555}),
#  Document(page_content='And unlike the $2 Trillion tax cut passed in the previous administration that benefitted the top 1%', metadata={'start_index': 8624}),
#  Document(page_content='the top 1% of Americans, the American Rescue Plan helped working people—and left no one behind.', metadata={'start_index': 8713}),
#  Document(page_content='And it worked. It created jobs. Lots of jobs.', metadata={'start_index': 8811}),
#  Document(page_content='In fact—our economy created over 6.5 Million new jobs just last year, more jobs created in one year', metadata={'start_index': 8859}),
#  Document(page_content='created in one year', metadata={'start_index': 8939}),
#  Document(page_content='than ever before in the history of America.', metadata={'start_index': 8961}),
#  Document(page_content='Our economy grew at a rate of 5.7% last year, the strongest growth in nearly 40 years, the first', metadata={'start_index': 9007}),
#  Document(page_content='40 years, the first step in bringing fundamental change to an economy that hasn’t worked for the', metadata={'start_index': 9084}),
#  Document(page_content='worked for the working people of this nation for too long.', metadata={'start_index': 9166}),
#  Document(page_content='For the past 40 years we were told that if we gave tax breaks to those at the very top, the', metadata={'start_index': 9228}),
#  Document(page_content='the very top, the benefits would trickle down to everyone else.', metadata={'start_index': 9302}),
#  Document(page_content='But that trickle-down theory led to weaker economic growth, lower wages, bigger deficits, and the', metadata={'start_index': 9368}),
#  Document(page_content='deficits, and the widest gap between those at the top and everyone else in nearly a century.', metadata={'start_index': 9448}),
#  Document(page_content='Vice President Harris and I ran for office with a new economic vision for America.', metadata={'start_index': 9543}),
#  Document(page_content='Invest in America. Educate Americans. Grow the workforce. Build the economy from the bottom up', metadata={'start_index': 9628}),
#  Document(page_content='and the middle out, not from the top down.', metadata={'start_index': 9725}),
#  Document(page_content='Because we know that when the middle class grows, the poor have a ladder up and the wealthy do very', metadata={'start_index': 9771}),
#  Document(page_content='the wealthy do very well.', metadata={'start_index': 9851}),
#  Document(page_content='America used to have the best roads, bridges, and airports on Earth.', metadata={'start_index': 9879}),
#  Document(page_content='Now our infrastructure is ranked 13th in the world.', metadata={'start_index': 9950}),
#  Document(page_content='We won’t be able to compete for the jobs of the 21st Century if we don’t fix that.', metadata={'start_index': 10004}),
#  Document(page_content='That’s why it was so important to pass the Bipartisan Infrastructure Law—the most sweeping', metadata={'start_index': 10089}),
#  Document(page_content='most sweeping investment to rebuild America in history.', metadata={'start_index': 10166}),
#  Document(page_content='This was a bipartisan effort, and I want to thank the members of both parties who worked to make it', metadata={'start_index': 10224}),
#  Document(page_content='worked to make it happen.', metadata={'start_index': 10306}),
#  Document(page_content='We’re done talking about infrastructure weeks. \n\nWe’re going to have an infrastructure decade.', metadata={'start_index': 10334}),
#  Document(page_content='It is going to transform America and put us on a path to win the economic competition of the 21st', metadata={'start_index': 10431}),
#  Document(page_content='of the 21st Century that we face with the rest of the world—particularly with China.', metadata={'start_index': 10517}),
#  Document(page_content='As I’ve told Xi Jinping, it is never a good bet to bet against the American people.', metadata={'start_index': 10605}),
#  Document(page_content='We’ll create good jobs for millions of Americans, modernizing roads, airports, ports, and waterways', metadata={'start_index': 10691}),
#  Document(page_content='and waterways all across America.', metadata={'start_index': 10777}),
#  Document(page_content='And we’ll do it all to withstand the devastating effects of the climate crisis and promote', metadata={'start_index': 10813}),
#  Document(page_content='crisis and promote environmental justice.', metadata={'start_index': 10885}),
#  Document(page_content='We’ll build a national network of 500,000 electric vehicle charging stations, begin to replace', metadata={'start_index': 10929}),
#  Document(page_content='begin to replace poisonous lead pipes—so every child—and every American—has clean water to drink at', metadata={'start_index': 11007}),
#  Document(page_content='water to drink at home and at school, provide affordable high-speed internet for every', metadata={'start_index': 11089}),
#  Document(page_content='internet for every American—urban, suburban, rural, and tribal communities.', metadata={'start_index': 11157}),
#  Document(page_content='4,000 projects have already been announced.', metadata={'start_index': 11235}),
#  Document(page_content='And tonight, I’m announcing that this year we will start fixing over 65,000 miles of highway and', metadata={'start_index': 11281}),
#  Document(page_content='of highway and 1,500 bridges in disrepair.', metadata={'start_index': 11363}),
#  Document(page_content='When we use taxpayer dollars to rebuild America – we are going to Buy American: buy American', metadata={'start_index': 11408}),
#  Document(page_content='buy American products to support American jobs.', metadata={'start_index': 11488}),
#  Document(page_content='The federal government spends about $600 Billion a year to keep the country safe and secure.', metadata={'start_index': 11538}),
#  Document(page_content='There’s been a law on the books for almost a century', metadata={'start_index': 11633}),
#  Document(page_content='to make sure taxpayers’ dollars support American jobs and businesses.', metadata={'start_index': 11687}),
#  Document(page_content='Every Administration says they’ll do it, but we are actually doing it.', metadata={'start_index': 11759}),
#  Document(page_content='We will buy American to make sure everything from the deck of an aircraft carrier to the steel on', metadata={'start_index': 11832}),
#  Document(page_content='to the steel on highway guardrails are made in America.', metadata={'start_index': 11914}),
#  Document(page_content='But to compete for the best jobs of the future, we also need to level the playing field with China', metadata={'start_index': 11972}),
#  Document(page_content='field with China and other competitors.', metadata={'start_index': 12054}),
#  Document(page_content='That’s why it is so important to pass the Bipartisan Innovation Act sitting in Congress that will', metadata={'start_index': 12096}),
#  Document(page_content='Congress that will make record investments in emerging technologies and American manufacturing.', metadata={'start_index': 12175}),
#  Document(page_content='Let me give you one example of why it’s so important to pass it.', metadata={'start_index': 12273}),
#  Document(page_content='If you travel 20 miles east of Columbus, Ohio, you’ll find 1,000 empty acres of land.', metadata={'start_index': 12340}),
#  Document(page_content='It won’t look like much, but if you stop and look closely, you’ll see a “Field of dreams,” the', metadata={'start_index': 12428}),
#  Document(page_content='of dreams,” the ground on which America’s future will be built.', metadata={'start_index': 12507}),
#  Document(page_content='This is where Intel, the American company that helped build Silicon Valley, is going to build its', metadata={'start_index': 12573}),
#  Document(page_content='going to build its $20 billion semiconductor “mega site”.', metadata={'start_index': 12652}),
#  Document(page_content='Up to eight state-of-the-art factories in one place. 10,000 new good-paying jobs.', metadata={'start_index': 12712}),
#  Document(page_content='Some of the most sophisticated manufacturing in the world to make computer chips the size of a', metadata={'start_index': 12796}),
#  Document(page_content='chips the size of a fingertip that power the world and our everyday lives.', metadata={'start_index': 12871}),
#  Document(page_content='Smartphones. The Internet. Technology we have yet to invent. \n\nBut that’s just the beginning.', metadata={'start_index': 12948}),
#  Document(page_content='Intel’s CEO, Pat Gelsinger, who is here tonight, told me they are ready to increase their', metadata={'start_index': 13044}),
#  Document(page_content='to increase their investment from', metadata={'start_index': 13116}),
#  Document(page_content='$20 billion to $100 billion.', metadata={'start_index': 13152}),
#  Document(page_content='That would be one of the biggest investments in manufacturing in American history.', metadata={'start_index': 13183}),
#  Document(page_content='And all they’re waiting for is for you to pass this bill.', metadata={'start_index': 13268}),
#  Document(page_content='So let’s not wait any longer. Send it to my desk. I’ll sign it.  \n\nAnd we will really take off.', metadata={'start_index': 13328}),
#  Document(page_content='And Intel is not alone. \n\nThere’s something happening in America.', metadata={'start_index': 13426}),
#  Document(page_content='Just look around and you’ll see an amazing story.', metadata={'start_index': 13494}),
#  Document(page_content='The rebirth of the pride that comes from stamping products “Made In America.” The revitalization of', metadata={'start_index': 13546}),
#  Document(page_content='revitalization of American manufacturing.', metadata={'start_index': 13628}),
#  Document(page_content='Companies are choosing to build new factories here, when just a few years ago, they would have', metadata={'start_index': 13674}),
#  Document(page_content='they would have built them overseas.', metadata={'start_index': 13753}),
#  Document(page_content='That’s what is happening. Ford is investing $11 billion to build electric vehicles, creating 11,000', metadata={'start_index': 13792}),
#  Document(page_content='creating 11,000 jobs across the country.', metadata={'start_index': 13876}),
#  Document(page_content='GM is making the largest investment in its history—$7 billion to build electric vehicles, creating', metadata={'start_index': 13919}),
#  Document(page_content='vehicles, creating 4,000 jobs in Michigan.', metadata={'start_index': 13999}),
#  Document(page_content='All told, we created 369,000 new manufacturing jobs in America just last year.', metadata={'start_index': 14044}),
#  Document(page_content='Powered by people I’ve met like JoJo Burgess, from generations of union steelworkers from', metadata={'start_index': 14125}),
#  Document(page_content='steelworkers from Pittsburgh, who’s here with us tonight.', metadata={'start_index': 14197}),
#  Document(page_content='As Ohio Senator Sherrod Brown says, “It’s time to bury the label “Rust Belt.” \n\nIt’s time.', metadata={'start_index': 14257}),
#  Document(page_content='But with all the bright spots in our economy, record job growth and higher wages, too many families', metadata={'start_index': 14350}),
#  Document(page_content='too many families are struggling to keep up with the bills.', metadata={'start_index': 14432}),
#  Document(page_content='Inflation is robbing them of the gains they might otherwise feel.', metadata={'start_index': 14495}),
#  Document(page_content='I get it. That’s why my top priority is getting prices under control.', metadata={'start_index': 14563}),
#  Document(page_content='Look, our economy roared back faster than most predicted, but the pandemic meant that businesses', metadata={'start_index': 14635}),
#  Document(page_content='that businesses had a hard time hiring enough workers to keep up production in their factories.', metadata={'start_index': 14716}),
#  Document(page_content='The pandemic also disrupted global supply chains.', metadata={'start_index': 14814}),
#  Document(page_content='When factories close, it takes longer to make goods and get them from the warehouse to the store,', metadata={'start_index': 14866}),
#  Document(page_content='to the store, and prices go up.', metadata={'start_index': 14950}),
#  Document(page_content='Look at cars.', metadata={'start_index': 14984}),
#  Document(page_content='Last year, there weren’t enough semiconductors to make all the cars that people wanted to buy.', metadata={'start_index': 15000}),
#  Document(page_content='And guess what, prices of automobiles went up. \n\nSo—we have a choice.', metadata={'start_index': 15097}),
#  Document(page_content='One way to fight inflation is to drive down wages and make Americans poorer.', metadata={'start_index': 15169}),
#  Document(page_content='I have a better plan to fight inflation. \n\nLower your costs, not your wages.', metadata={'start_index': 15249}),
#  Document(page_content='Make more cars and semiconductors in America. \n\nMore infrastructure and innovation in America.', metadata={'start_index': 15328}),
#  Document(page_content='More goods moving faster and cheaper in America.', metadata={'start_index': 15425}),
#  Document(page_content='More jobs where you can earn a good living in America.', metadata={'start_index': 15476}),
#  Document(page_content='And instead of relying on foreign supply chains, let’s make it in America.', metadata={'start_index': 15533}),
#  Document(page_content='Economists call it “increasing the productive capacity of our economy.”', metadata={'start_index': 15610}),
#  Document(page_content='I call it building a better America.', metadata={'start_index': 15684}),
#  Document(page_content='My plan to fight inflation will lower your costs and lower the deficit.', metadata={'start_index': 15723}),
#  Document(page_content='17 Nobel laureates in economics say my plan will ease long-term inflationary pressures. Top', metadata={'start_index': 15797}),
#  Document(page_content='pressures. Top business leaders and most Americans support my plan. And here’s the plan:', metadata={'start_index': 15874}),
#  Document(page_content='First – cut the cost of prescription drugs. Just look at insulin. One in ten Americans has', metadata={'start_index': 15965}),
#  Document(page_content='ten Americans has diabetes. In Virginia, I met a 13-year-old boy named Joshua Davis.', metadata={'start_index': 16038}),
#  Document(page_content='He and his Dad both have Type 1 diabetes, which means they need insulin every day. Insulin costs', metadata={'start_index': 16126}),
#  Document(page_content='day. Insulin costs about $10 a vial to make.', metadata={'start_index': 16204}),
#  Document(page_content='But drug companies charge families like Joshua and his Dad up to 30 times more. I spoke with', metadata={'start_index': 16252}),
#  Document(page_content='more. I spoke with Joshua’s mom.', metadata={'start_index': 16326}),
#  Document(page_content='Imagine what it’s like to look at your child who needs insulin and have no idea how you’re going to', metadata={'start_index': 16361}),
#  Document(page_content='how you’re going to pay for it.', metadata={'start_index': 16441}),
#  Document(page_content='What it does to your dignity, your ability to look your child in the eye, to be the parent you', metadata={'start_index': 16476}),
#  Document(page_content='be the parent you expect to be.', metadata={'start_index': 16553}),
#  Document(page_content='Joshua is here with us tonight. Yesterday was his birthday. Happy birthday, buddy.', metadata={'start_index': 16587}),
#  Document(page_content='For Joshua, and for the 200,000 other young people with Type 1 diabetes, let’s cap the cost of', metadata={'start_index': 16673}),
#  Document(page_content='cap the cost of insulin at $35 a month so everyone can afford it.', metadata={'start_index': 16752}),
#  Document(page_content='Drug companies will still do very well. And while we’re at it let Medicare negotiate lower prices', metadata={'start_index': 16821}),
#  Document(page_content='lower prices for prescription drugs, like the VA already does.', metadata={'start_index': 16906}),
#  Document(page_content='Look, the American Rescue Plan is helping millions of families on Affordable Care Act plans save', metadata={'start_index': 16971}),
#  Document(page_content='Care Act plans save $2,400 a year on their health care premiums. Let’s close the coverage gap and', metadata={'start_index': 17048}),
#  Document(page_content='coverage gap and make those savings permanent.', metadata={'start_index': 17129}),
#  Document(page_content='Second – cut energy costs for families an average of $500 a year by combatting climate change.', metadata={'start_index': 17178}),
#  Document(page_content='Let’s provide investments and tax credits to weatherize your homes and businesses to be energy', metadata={'start_index': 17276}),
#  Document(page_content='to be energy efficient and you get a tax credit; double America’s clean energy production in solar,', metadata={'start_index': 17358}),
#  Document(page_content='in solar, wind, and so much more;  lower the price of electric vehicles, saving you another $80 a', metadata={'start_index': 17448}),
#  Document(page_content='you another $80 a month because you’ll never have to pay at the gas pump again.', metadata={'start_index': 17528}),
#  Document(page_content='Third – cut the cost of child care. Many families pay up to $14,000 a year for child care per', metadata={'start_index': 17610}),
#  Document(page_content='for child care per child.', metadata={'start_index': 17685}),
#  Document(page_content='Middle-class and working families shouldn’t have to pay more than 7% of their income for care of', metadata={'start_index': 17714}),
#  Document(page_content='income for care of young children.', metadata={'start_index': 17792}),
#  Document(page_content='My plan will cut the cost in half for most families and help parents, including millions of women,', metadata={'start_index': 17830}),
#  Document(page_content='millions of women, who left the workforce during the pandemic because they couldn’t afford child', metadata={'start_index': 17910}),
#  Document(page_content='afford child care, to be able to get back to work.', metadata={'start_index': 17994}),
#  Document(page_content='My plan doesn’t stop there. It also includes home and long-term care. More affordable housing. And', metadata={'start_index': 18047}),
#  Document(page_content='housing. And Pre-K for every 3- and 4-year-old.', metadata={'start_index': 18133}),
#  Document(page_content='All of these will lower costs.', metadata={'start_index': 18184}),
#  Document(page_content='And under my plan, nobody earning less than $400,000 a year will pay an additional penny in new', metadata={'start_index': 18217}),
#  Document(page_content='penny in new taxes. Nobody.', metadata={'start_index': 18300}),
#  Document(page_content='The one thing all Americans agree on is that the tax system is not fair. We have to fix it.', metadata={'start_index': 18331}),
#  Document(page_content='I’m not looking to punish anyone. But let’s make sure corporations and the wealthiest Americans', metadata={'start_index': 18426}),
#  Document(page_content='Americans start paying their fair share.', metadata={'start_index': 18512}),
#  Document(page_content='Just last year, 55 Fortune 500 corporations earned $40 billion in profits and paid zero dollars in', metadata={'start_index': 18555}),
#  Document(page_content='zero dollars in federal income tax.', metadata={'start_index': 18638}),
#  Document(page_content='That’s simply not fair. That’s why I’ve proposed a 15% minimum tax rate for corporations.', metadata={'start_index': 18677}),
#  Document(page_content='We got more than 130 countries to agree on a global minimum tax rate so companies can’t get out of', metadata={'start_index': 18769}),
#  Document(page_content='can’t get out of paying their taxes at home by shipping jobs and factories overseas.', metadata={'start_index': 18851}),
#  Document(page_content='That’s why I’ve proposed closing loopholes so the very wealthy don’t pay a lower tax rate than a', metadata={'start_index': 18938}),
#  Document(page_content='tax rate than a teacher or a firefighter.', metadata={'start_index': 19019}),
#  Document(page_content='So that’s my plan. It will grow the economy and lower costs for families.', metadata={'start_index': 19064}),
#  Document(page_content='So what are we waiting for? Let’s get this done. And while you’re at it, confirm my nominees to the', metadata={'start_index': 19140}),
#  Document(page_content='my nominees to the Federal Reserve, which plays a critical role in fighting inflation.', metadata={'start_index': 19221}),
#  Document(page_content='My plan will not only lower costs to give families a fair shot, it will lower the deficit.', metadata={'start_index': 19311}),
#  Document(page_content='The previous Administration not only ballooned the deficit with tax cuts for the very wealthy and', metadata={'start_index': 19404}),
#  Document(page_content='very wealthy and corporations, it undermined the watchdogs whose job was to keep pandemic relief', metadata={'start_index': 19485}),
#  Document(page_content='pandemic relief funds from being wasted.', metadata={'start_index': 19566}),
#  Document(page_content='But in my administration, the watchdogs have been welcomed back.', metadata={'start_index': 19609}),
#  Document(page_content='We’re going after the criminals who stole billions in relief money meant for small businesses and', metadata={'start_index': 19676}),
#  Document(page_content='businesses and millions of Americans.', metadata={'start_index': 19759}),
#  Document(page_content='And tonight, I’m announcing that the Justice Department will name a chief prosecutor for pandemic', metadata={'start_index': 19800}),
#  Document(page_content='for pandemic fraud.', metadata={'start_index': 19885}),
#  Document(page_content='By the end of this year, the deficit will be down to less than half what it was before I took', metadata={'start_index': 19907}),
#  Document(page_content='was before I took office.', metadata={'start_index': 19983}),
#  Document(page_content='The only president ever to cut the deficit by more than one trillion dollars in a single year.', metadata={'start_index': 20012}),
#  Document(page_content='Lowering your costs also means demanding more competition.', metadata={'start_index': 20109}),
#  Document(page_content='I’m a capitalist, but capitalism without competition isn’t capitalism.', metadata={'start_index': 20170}),
#  Document(page_content='It’s exploitation—and it drives up prices.', metadata={'start_index': 20243}),
#  Document(page_content='When corporations don’t have to compete, their profits go up, your prices go up, and small', metadata={'start_index': 20288}),
#  Document(page_content='go up, and small businesses and family farmers and ranchers go under.', metadata={'start_index': 20362}),
#  Document(page_content='We see it happening with ocean carriers moving goods in and out of America.', metadata={'start_index': 20434}),
#  Document(page_content='During the pandemic, these foreign-owned companies raised prices by as much as 1,000% and made', metadata={'start_index': 20512}),
#  Document(page_content='as 1,000% and made record profits.', metadata={'start_index': 20588}),
#  Document(page_content='Tonight, I’m announcing a crackdown on these companies overcharging American businesses and', metadata={'start_index': 20625}),
#  Document(page_content='businesses and consumers.', metadata={'start_index': 20702}),
#  Document(page_content='And as Wall Street firms take over more nursing homes, quality in those homes has gone down and', metadata={'start_index': 20730}),
#  Document(page_content='has gone down and costs have gone up.', metadata={'start_index': 20808}),
#  Document(page_content='That ends on my watch.', metadata={'start_index': 20849}),
#  Document(page_content='Medicare is going to set higher standards for nursing homes and make sure your loved ones get the', metadata={'start_index': 20874}),
#  Document(page_content='loved ones get the care they deserve and expect.', metadata={'start_index': 20953}),
#  Document(page_content='We’ll also cut costs and keep the economy going strong by giving workers a fair shot, provide more', metadata={'start_index': 21004}),
#  Document(page_content='shot, provide more training and apprenticeships, hire them based on their skills not degrees.', metadata={'start_index': 21084}),
#  Document(page_content='Let’s pass the Paycheck Fairness Act and paid leave.', metadata={'start_index': 21180}),
#  Document(page_content='Raise the minimum wage to $15 an hour and extend the Child Tax Credit, so no one has to raise a', metadata={'start_index': 21236}),
#  Document(page_content='one has to raise a family in poverty.', metadata={'start_index': 21313}),
#  Document(page_content='Let’s increase Pell Grants and increase our historic support of HBCUs, and invest in what Jill—our', metadata={'start_index': 21353}),
#  Document(page_content='in what Jill—our First Lady who teaches full-time—calls America’s best-kept secret: community', metadata={'start_index': 21435}),
#  Document(page_content='secret: community colleges.', metadata={'start_index': 21511}),
#  Document(page_content='And let’s pass the PRO Act when a majority of workers want to form a union—they shouldn’t be', metadata={'start_index': 21541}),
#  Document(page_content='shouldn’t be stopped.', metadata={'start_index': 21621}),
#  Document(page_content='When we invest in our workers, when we build the economy from the bottom up and the middle out', metadata={'start_index': 21646}),
#  Document(page_content='and the middle out together, we can do something we haven’t done in a long time: build a better', metadata={'start_index': 21722}),
#  Document(page_content='build a better America.', metadata={'start_index': 21803}),
#  Document(page_content='For more than two years, COVID-19 has impacted every decision in our lives and the life of the', metadata={'start_index': 21829}),
#  Document(page_content='and the life of the nation.', metadata={'start_index': 21904}),
#  Document(page_content='And I know you’re tired, frustrated, and exhausted. \n\nBut I also know this.', metadata={'start_index': 21934}),
#  Document(page_content='Because of the progress we’ve made, because of your resilience and the tools we have, tonight I can', metadata={'start_index': 22012}),
#  Document(page_content='have, tonight I can say', metadata={'start_index': 22092}),
#  Document(page_content='we are moving forward safely, back to more normal routines.', metadata={'start_index': 22118}),
#  Document(page_content='We’ve reached a new moment in the fight against COVID-19, with severe cases down to a level not', metadata={'start_index': 22181}),
#  Document(page_content='down to a level not seen since last July.', metadata={'start_index': 22257}),
#  Document(page_content='Just a few days ago, the Centers for Disease Control and Prevention—the CDC—issued new mask', metadata={'start_index': 22302}),
#  Document(page_content='CDC—issued new mask guidelines.', metadata={'start_index': 22374}),
#  Document(page_content='Under these new guidelines, most Americans in most of the country can now be mask free.', metadata={'start_index': 22408}),
#  Document(page_content='And based on the projections, more of the country will reach that point across the next couple of', metadata={'start_index': 22500}),
#  Document(page_content='the next couple of weeks.', metadata={'start_index': 22579}),
#  Document(page_content='Thanks to the progress we have made this past year, COVID-19 need no longer control our lives.', metadata={'start_index': 22607}),
#  Document(page_content='I know some are talking about “living with COVID-19”. Tonight – I say that we will never just', metadata={'start_index': 22705}),
#  Document(page_content='we will never just accept living with COVID-19.', metadata={'start_index': 22780}),
#  Document(page_content='We will continue to combat the virus as we do other diseases. And because this is a virus that', metadata={'start_index': 22830}),
#  Document(page_content='is a virus that mutates and spreads, we will stay on guard.', metadata={'start_index': 22909}),
#  Document(page_content='Here are four common sense steps as we move forward safely.', metadata={'start_index': 22971}),
#  Document(page_content='First, stay protected with vaccines and treatments. We know how incredibly effective vaccines are.', metadata={'start_index': 23034}),
#  Document(page_content='vaccines are. If you’re vaccinated and boosted you have the highest degree of protection.', metadata={'start_index': 23119}),
#  Document(page_content='We will never give up on vaccinating more Americans. Now, I know parents with kids under 5 are', metadata={'start_index': 23211}),
#  Document(page_content='kids under 5 are eager to see a vaccine authorized for their children.', metadata={'start_index': 23289}),
#  Document(page_content='The scientists are working hard to get that done and we’ll be ready with plenty of vaccines when', metadata={'start_index': 23362}),
#  Document(page_content='of vaccines when they do.', metadata={'start_index': 23442}),
#  Document(page_content='We’re also ready with anti-viral treatments. If you get COVID-19, the Pfizer pill reduces your', metadata={'start_index': 23470}),
#  Document(page_content='pill reduces your chances of ending up in the hospital by 90%.', metadata={'start_index': 23547}),
#  Document(page_content='We’ve ordered more of these pills than anyone in the world. And Pfizer is working overtime to get', metadata={'start_index': 23613}),
#  Document(page_content='overtime to get us 1 Million pills this month and more than double that next month.', metadata={'start_index': 23695}),
#  Document(page_content='And we’re launching the “Test to Treat” initiative so people can get tested at a pharmacy, and if', metadata={'start_index': 23782}),
#  Document(page_content='a pharmacy, and if they’re positive, receive antiviral pills on the spot at no cost.', metadata={'start_index': 23861}),
#  Document(page_content='If you’re immunocompromised or have some other vulnerability, we have treatments and free', metadata={'start_index': 23949}),
#  Document(page_content='treatments and free high-quality masks.', metadata={'start_index': 24019}),
#  Document(page_content='We’re leaving no one behind or ignoring anyone’s needs as we move forward.', metadata={'start_index': 24061}),
#  Document(page_content='And on testing, we have made hundreds of millions of tests available for you to order for free.', metadata={'start_index': 24138}),
#  Document(page_content='Even if you already ordered free tests tonight, I am announcing that you can order more from', metadata={'start_index': 24238}),
#  Document(page_content='can order more from covidtests.gov starting next week.', metadata={'start_index': 24311}),
#  Document(page_content='Second – we must prepare for new variants. Over the past year, we’ve gotten much better at', metadata={'start_index': 24368}),
#  Document(page_content='much better at detecting new variants.', metadata={'start_index': 24444}),
# ...
#  Document(page_content='and violence can have their cases heard faster.', metadata={'start_index': 30414}),
#  Document(page_content='We’re securing commitments and supporting partners in South and Central America to host more', metadata={'start_index': 30464}),
#  Document(page_content='to host more refugees and secure their own borders.', metadata={'start_index': 30544}),
#  Document(page_content='We can do all this while keeping lit the torch of liberty that has led generations of immigrants to', metadata={'start_index': 30598}),
#  Document(page_content='of immigrants to this land—my forefathers and so many of yours.', metadata={'start_index': 30681}),
#  Document(page_content='Provide a pathway to citizenship for Dreamers, those on temporary status, farm workers, and', metadata={'start_index': 30747}),
#  Document(page_content='farm workers, and essential workers.', metadata={'start_index': 30821}),
#  Document(page_content='Revise our laws so businesses have the workers they need and families don’t wait decades to', metadata={'start_index': 30860}),
#  Document(page_content='wait decades to reunite.', metadata={'start_index': 30936}),
#  Document(page_content='It’s not only the right thing to do—it’s the economically smart thing to do.', metadata={'start_index': 30963}),
#  Document(page_content='That’s why immigration reform is supported by everyone from labor unions to religious leaders to', metadata={'start_index': 31042}),
#  Document(page_content='leaders to the U.S. Chamber of Commerce.', metadata={'start_index': 31128}),
#  Document(page_content='Let’s get it done once and for all.', metadata={'start_index': 31171}),
#  Document(page_content='Advancing liberty and justice also requires protecting the rights of women.', metadata={'start_index': 31209}),
#  Document(page_content='The constitutional right affirmed in Roe v. Wade—standing precedent for half a century—is under', metadata={'start_index': 31287}),
#  Document(page_content='a century—is under attack as never before.', metadata={'start_index': 31364}),
#  Document(page_content='If we want to go forward—not backward—we must protect access to health care. Preserve a woman’s', metadata={'start_index': 31409}),
#  Document(page_content='Preserve a woman’s right to choose. And let’s continue to advance maternal health care in America.', metadata={'start_index': 31486}),
#  Document(page_content='And for our LGBTQ+ Americans, let’s finally get the bipartisan Equality Act to my desk. The', metadata={'start_index': 31587}),
#  Document(page_content='Act to my desk. The onslaught of state laws targeting transgender Americans and their families is', metadata={'start_index': 31659}),
#  Document(page_content='their families is wrong.', metadata={'start_index': 31739}),
#  Document(page_content='As I said last year, especially to our younger transgender Americans, I will always have your back', metadata={'start_index': 31766}),
#  Document(page_content='have your back as your President, so you can be yourself and reach your God-given potential.', metadata={'start_index': 31850}),
#  Document(page_content='While it often appears that we never agree, that isn’t true. I signed 80 bipartisan bills into law', metadata={'start_index': 31945}),
#  Document(page_content='bills into law last year. From preventing government shutdowns to protecting Asian-Americans from', metadata={'start_index': 32029}),
#  Document(page_content='from still-too-common hate crimes to reforming military justice.', metadata={'start_index': 32122}),
#  Document(page_content='And soon, we’ll strengthen the Violence Against Women Act that I first wrote three decades ago. It', metadata={'start_index': 32189}),
#  Document(page_content='decades ago. It is important for us to show the nation that we can come together and do big things.', metadata={'start_index': 32272}),
#  Document(page_content='and do big things.', metadata={'start_index': 32353}),
#  Document(page_content='So tonight I’m offering a Unity Agenda for the Nation. Four big things we can do together.', metadata={'start_index': 32374}),
#  Document(page_content='First, beat the opioid epidemic.', metadata={'start_index': 32468}),
#  Document(page_content='There is so much we can do. Increase funding for prevention, treatment, harm reduction, and', metadata={'start_index': 32503}),
#  Document(page_content='harm reduction, and recovery.', metadata={'start_index': 32575}),
#  Document(page_content='Get rid of outdated rules that stop doctors from prescribing treatments. And stop the flow of', metadata={'start_index': 32608}),
#  Document(page_content='stop the flow of illicit drugs by working with state and local law enforcement to go after', metadata={'start_index': 32685}),
#  Document(page_content='to go after traffickers.', metadata={'start_index': 32764}),
#  Document(page_content='If you’re suffering from addiction, know you are not alone. I believe in recovery, and I celebrate', metadata={'start_index': 32791}),
#  Document(page_content='and I celebrate the 23 million Americans in recovery.', metadata={'start_index': 32874}),
#  Document(page_content='Second, let’s take on mental health. Especially among our children, whose lives and education have', metadata={'start_index': 32930}),
#  Document(page_content='and education have been turned upside down.', metadata={'start_index': 33010}),
#  Document(page_content='The American Rescue Plan gave schools money to hire teachers and help students make up for lost', metadata={'start_index': 33057}),
#  Document(page_content='make up for lost learning.', metadata={'start_index': 33136}),
#  Document(page_content='I urge every parent to make sure your school does just that. And we can all play a part—sign up to', metadata={'start_index': 33166}),
#  Document(page_content='a part—sign up to be a tutor or a mentor.', metadata={'start_index': 33247}),
#  Document(page_content='Children were also struggling before the pandemic. Bullying, violence, trauma, and the harms of', metadata={'start_index': 33291}),
#  Document(page_content='and the harms of social media.', metadata={'start_index': 33370}),
#  Document(page_content='As Frances Haugen, who is here with us tonight, has shown, we must hold social media platforms', metadata={'start_index': 33403}),
#  Document(page_content='media platforms accountable for the national experiment they’re conducting on our children for', metadata={'start_index': 33482}),
#  Document(page_content='on our children for profit.', metadata={'start_index': 33557}),
#  Document(page_content='It’s time to strengthen privacy protections, ban targeted advertising to children, demand tech', metadata={'start_index': 33587}),
#  Document(page_content='demand tech companies stop collecting personal data on our children.', metadata={'start_index': 33670}),
#  Document(page_content='And let’s get all Americans the mental health services they need. More people they can turn to for', metadata={'start_index': 33741}),
#  Document(page_content='can turn to for help, and full parity between physical and mental health care.', metadata={'start_index': 33824}),
#  Document(page_content='Third, support our veterans. \n\nVeterans are the best of us.', metadata={'start_index': 33905}),
#  Document(page_content='I’ve always believed that we have a sacred obligation to equip all those we send to war and care', metadata={'start_index': 33967}),
#  Document(page_content='to war and care for them and their families when they come home.', metadata={'start_index': 34048}),
#  Document(page_content='My administration is providing assistance with job training and housing, and now helping', metadata={'start_index': 34115}),
#  Document(page_content='and now helping lower-income veterans get VA care debt-free.', metadata={'start_index': 34188}),
#  Document(page_content='Our troops in Iraq and Afghanistan faced many dangers.', metadata={'start_index': 34252}),
#  Document(page_content='One was stationed at bases and breathing in toxic smoke from “burn pits” that incinerated wastes of', metadata={'start_index': 34309}),
#  Document(page_content='wastes of war—medical and hazard material, jet fuel, and more.', metadata={'start_index': 34399}),
#  Document(page_content='When they came home, many of the world’s fittest and best trained warriors were never the same.', metadata={'start_index': 34464}),
#  Document(page_content='Headaches. Numbness. Dizziness. \n\nA cancer that would put them in a flag-draped coffin. \n\nI know.', metadata={'start_index': 34562}),
#  Document(page_content='I know. \n\nOne of those soldiers was my son Major Beau Biden.', metadata={'start_index': 34652}),
#  Document(page_content='We don’t know for sure if a burn pit was the cause of his brain cancer, or the diseases of so many', metadata={'start_index': 34715}),
#  Document(page_content='diseases of so many of our troops.', metadata={'start_index': 34794}),
#  Document(page_content='But I’m committed to finding out everything we can.', metadata={'start_index': 34831}),
#  Document(page_content='Committed to military families like Danielle Robinson from Ohio.', metadata={'start_index': 34885}),
#  Document(page_content='The widow of Sergeant First Class Heath Robinson.', metadata={'start_index': 34952}),
#  Document(page_content='He was born a soldier. Army National Guard. Combat medic in Kosovo and Iraq.', metadata={'start_index': 35005}),
#  Document(page_content='Stationed near Baghdad, just yards from burn pits the size of football fields.', metadata={'start_index': 35084}),
#  Document(page_content='Heath’s widow Danielle is here with us tonight. They loved going to Ohio State football games. He', metadata={'start_index': 35165}),
#  Document(page_content='football games. He loved building Legos with their daughter.', metadata={'start_index': 35244}),
#  Document(page_content='But cancer from prolonged exposure to burn pits ravaged Heath’s lungs and body.', metadata={'start_index': 35307}),
#  Document(page_content='Danielle says Heath was a fighter to the very end.', metadata={'start_index': 35389}),
#  Document(page_content='He didn’t know how to stop fighting, and neither did she.', metadata={'start_index': 35442}),
#  Document(page_content='Through her pain she found purpose to demand we do better. \n\nTonight, Danielle—we are.', metadata={'start_index': 35502}),
#  Document(page_content='The VA is pioneering new ways of linking toxic exposures to diseases, already helping more veterans', metadata={'start_index': 35591}),
#  Document(page_content='more veterans get benefits.', metadata={'start_index': 35677}),
#  Document(page_content='And tonight, I’m announcing we’re expanding eligibility to veterans suffering from nine respiratory', metadata={'start_index': 35707}),
#  Document(page_content='nine respiratory cancers.', metadata={'start_index': 35790}),
#  Document(page_content='I’m also calling on Congress: pass a law to make sure veterans devastated by toxic exposures in', metadata={'start_index': 35818}),
#  Document(page_content='toxic exposures in Iraq and Afghanistan finally get the benefits and comprehensive health care they', metadata={'start_index': 35895}),
#  Document(page_content='health care they deserve.', metadata={'start_index': 35978}),
#  Document(page_content='And fourth, let’s end cancer as we know it.', metadata={'start_index': 36006}),
#  Document(page_content='This is personal to me and Jill, to Kamala, and to so many of you.', metadata={'start_index': 36052}),
#  Document(page_content='Cancer is the #2 cause of death in America–second only to heart disease.', metadata={'start_index': 36121}),
#  Document(page_content='Last month, I announced our plan to supercharge', metadata={'start_index': 36196}),
#  Document(page_content='the Cancer Moonshot that President Obama asked me to lead six years ago.', metadata={'start_index': 36246}),
#  Document(page_content='Our goal is to cut the cancer death rate by at least 50% over the next 25 years, turn more cancers', metadata={'start_index': 36321}),
#  Document(page_content='turn more cancers from death sentences into treatable diseases.', metadata={'start_index': 36402}),
#  Document(page_content='More support for patients and families.', metadata={'start_index': 36469}),
#  Document(page_content='To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.', metadata={'start_index': 36511}),
#  Document(page_content='It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.', metadata={'start_index': 36612}),
#  Document(page_content='and so much more.', metadata={'start_index': 36694}),
#  Document(page_content='ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and', metadata={'start_index': 36715}),
#  Document(page_content='diabetes, and more.', metadata={'start_index': 36798}),
#  Document(page_content='A unity agenda for the nation. \n\nWe can do this.', metadata={'start_index': 36820}),
#  Document(page_content='My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.', metadata={'start_index': 36871}),
#  Document(page_content='In this Capitol, generation after generation, Americans have debated great questions amid great', metadata={'start_index': 36968}),
#  Document(page_content='amid great strife, and have done great things.', metadata={'start_index': 37053}),
#  Document(page_content='We have fought for freedom, expanded liberty, defeated totalitarianism and terror.', metadata={'start_index': 37102}),
#  Document(page_content='And built the strongest, freest, and most prosperous nation the world has ever known.', metadata={'start_index': 37187}),
#  Document(page_content='Now is the hour. \n\nOur moment of responsibility.', metadata={'start_index': 37275}),
#  Document(page_content='Our test of resolve and conscience, of history itself.', metadata={'start_index': 37326}),
#  Document(page_content='It is in this moment that our character is formed. Our purpose is found. Our future is forged.', metadata={'start_index': 37383}),
#  Document(page_content='Well I know this nation.  \n\nWe will meet the test.', metadata={'start_index': 37480}),
#  Document(page_content='To protect freedom and liberty, to expand fairness and opportunity. \n\nWe will save democracy.', metadata={'start_index': 37533}),
#  Document(page_content='As hard as these times have been, I am more optimistic about America today than I have been my', metadata={'start_index': 37629}),
#  Document(page_content='than I have been my whole life.', metadata={'start_index': 37704}),
#  Document(page_content='Because I see the future that is within our grasp.', metadata={'start_index': 37738}),
#  Document(page_content='Because I know there is simply nothing beyond our capacity.', metadata={'start_index': 37791}),
#  Document(page_content='We are the only nation on Earth that has always turned every crisis we have faced into an', metadata={'start_index': 37853}),
#  Document(page_content='have faced into an opportunity.', metadata={'start_index': 37924}),
#  Document(page_content='The only nation that can be defined by a single word: possibilities.', metadata={'start_index': 37958}),
#  Document(page_content='So on this night, in our 245th year as a nation, I have come to report on the State of the Union.', metadata={'start_index': 38029}),
#  Document(page_content='And my report is this: the State of the Union is strong—because you, the American people, are', metadata={'start_index': 38129}),
#  Document(page_content='people, are strong.', metadata={'start_index': 38211}),
#  Document(page_content='We are stronger today than we were a year ago.', metadata={'start_index': 38233}),
#  Document(page_content='And we will be stronger a year from now than we are today.', metadata={'start_index': 38282}),
#  Document(page_content='Now is our moment to meet and overcome the challenges of our time. \n\nAnd we will, as one people.', metadata={'start_index': 38343}),
#  Document(page_content='One America. \n\nThe United States of America. \n\nMay God bless you all. May God protect our troops.', metadata={'start_index': 38442})]

# %%
from langchain.text_splitter import CharacterTextSplitter

# %%
text_splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap  = 20,
    length_function = len,
    add_start_index = True,
)

# %%
docs = text_splitter.create_documents([state_of_the_union])

docs
# Out:
# Created a chunk of size 164, which is longer than the specified 100
# Created a chunk of size 169, which is longer than the specified 100
# Created a chunk of size 122, which is longer than the specified 100
# Created a chunk of size 121, which is longer than the specified 100
# Created a chunk of size 139, which is longer than the specified 100
# Created a chunk of size 181, which is longer than the specified 100
# Created a chunk of size 101, which is longer than the specified 100
# Created a chunk of size 113, which is longer than the specified 100
# Created a chunk of size 129, which is longer than the specified 100
# Created a chunk of size 146, which is longer than the specified 100
# Created a chunk of size 136, which is longer than the specified 100
# Created a chunk of size 189, which is longer than the specified 100
# Created a chunk of size 215, which is longer than the specified 100
# Created a chunk of size 124, which is longer than the specified 100
# Created a chunk of size 118, which is longer than the specified 100
# Created a chunk of size 129, which is longer than the specified 100
# Created a chunk of size 128, which is longer than the specified 100
# Created a chunk of size 114, which is longer than the specified 100
# Created a chunk of size 155, which is longer than the specified 100
# Created a chunk of size 232, which is longer than the specified 100
# Created a chunk of size 139, which is longer than the specified 100
# Created a chunk of size 163, which is longer than the specified 100
# Created a chunk of size 113, which is longer than the specified 100
# Created a chunk of size 109, which is longer than the specified 100
# Created a chunk of size 142, which is longer than the specified 100
# Created a chunk of size 178, which is longer than the specified 100
# Created a chunk of size 162, which is longer than the specified 100
# Created a chunk of size 138, which is longer than the specified 100
# Created a chunk of size 145, which is longer than the specified 100
# Created a chunk of size 173, which is longer than the specified 100
# Created a chunk of size 146, which is longer than the specified 100
# Created a chunk of size 190, which is longer than the specified 100
# Created a chunk of size 152, which is longer than the specified 100
# Created a chunk of size 172, which is longer than the specified 100
# Created a chunk of size 115, which is longer than the specified 100
# Created a chunk of size 128, which is longer than the specified 100
# Created a chunk of size 133, which is longer than the specified 100
# Created a chunk of size 242, which is longer than the specified 100
# Created a chunk of size 151, which is longer than the specified 100
# Created a chunk of size 129, which is longer than the specified 100
# Created a chunk of size 105, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 106, which is longer than the specified 100
# Created a chunk of size 138, which is longer than the specified 100
# Created a chunk of size 156, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 142, which is longer than the specified 100
# Created a chunk of size 185, which is longer than the specified 100
# Created a chunk of size 146, which is longer than the specified 100
# Created a chunk of size 219, which is longer than the specified 100
# Created a chunk of size 138, which is longer than the specified 100
# Created a chunk of size 173, which is longer than the specified 100
# Created a chunk of size 141, which is longer than the specified 100
# Created a chunk of size 106, which is longer than the specified 100
# Created a chunk of size 133, which is longer than the specified 100
# Created a chunk of size 108, which is longer than the specified 100
# Created a chunk of size 172, which is longer than the specified 100
# Created a chunk of size 120, which is longer than the specified 100
# Created a chunk of size 114, which is longer than the specified 100
# Created a chunk of size 304, which is longer than the specified 100
# Created a chunk of size 125, which is longer than the specified 100
# Created a chunk of size 128, which is longer than the specified 100
# Created a chunk of size 124, which is longer than the specified 100
# Created a chunk of size 138, which is longer than the specified 100
# Created a chunk of size 122, which is longer than the specified 100
# Created a chunk of size 175, which is longer than the specified 100
# Created a chunk of size 143, which is longer than the specified 100
# Created a chunk of size 137, which is longer than the specified 100
# Created a chunk of size 150, which is longer than the specified 100
# Created a chunk of size 137, which is longer than the specified 100
# Created a chunk of size 126, which is longer than the specified 100
# Created a chunk of size 116, which is longer than the specified 100
# Created a chunk of size 125, which is longer than the specified 100
# Created a chunk of size 123, which is longer than the specified 100
# Created a chunk of size 130, which is longer than the specified 100
# Created a chunk of size 143, which is longer than the specified 100
# Created a chunk of size 177, which is longer than the specified 100
# Created a chunk of size 116, which is longer than the specified 100
# Created a chunk of size 166, which is longer than the specified 100
# Created a chunk of size 159, which is longer than the specified 100
# Created a chunk of size 124, which is longer than the specified 100
# Created a chunk of size 107, which is longer than the specified 100
# Created a chunk of size 113, which is longer than the specified 100
# Created a chunk of size 109, which is longer than the specified 100
# Created a chunk of size 146, which is longer than the specified 100
# Created a chunk of size 148, which is longer than the specified 100
# Created a chunk of size 205, which is longer than the specified 100
# Created a chunk of size 332, which is longer than the specified 100
# Created a chunk of size 102, which is longer than the specified 100
# Created a chunk of size 114, which is longer than the specified 100
# Created a chunk of size 215, which is longer than the specified 100
# Created a chunk of size 135, which is longer than the specified 100
# Created a chunk of size 112, which is longer than the specified 100
# Created a chunk of size 127, which is longer than the specified 100
# Created a chunk of size 120, which is longer than the specified 100
# Created a chunk of size 167, which is longer than the specified 100
# Created a chunk of size 124, which is longer than the specified 100
# Created a chunk of size 169, which is longer than the specified 100
# Created a chunk of size 203, which is longer than the specified 100
# Created a chunk of size 122, which is longer than the specified 100
# Created a chunk of size 105, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 144, which is longer than the specified 100
# Created a chunk of size 111, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 117, which is longer than the specified 100
# Created a chunk of size 128, which is longer than the specified 100
# Created a chunk of size 174, which is longer than the specified 100
# Created a chunk of size 115, which is longer than the specified 100
# Created a chunk of size 186, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 181, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 167, which is longer than the specified 100
# Created a chunk of size 119, which is longer than the specified 100
# Created a chunk of size 104, which is longer than the specified 100
# Created a chunk of size 105, which is longer than the specified 100
# Created a chunk of size 123, which is longer than the specified 100
# Created a chunk of size 139, which is longer than the specified 100
# Created a chunk of size 175, which is longer than the specified 100
# Created a chunk of size 149, which is longer than the specified 100
# Created a chunk of size 106, which is longer than the specified 100
# Created a chunk of size 141, which is longer than the specified 100
# Created a chunk of size 167, which is longer than the specified 100
# Created a chunk of size 165, which is longer than the specified 100
# Created a chunk of size 110, which is longer than the specified 100
# Created a chunk of size 128, which is longer than the specified 100
# Created a chunk of size 115, which is longer than the specified 100
# Created a chunk of size 106, which is longer than the specified 100
# Created a chunk of size 115, which is longer than the specified 100
# Created a chunk of size 127, which is longer than the specified 100
# Created a chunk of size 156, which is longer than the specified 100
# Created a chunk of size 118, which is longer than the specified 100
# Created a chunk of size 186, which is longer than the specified 100
# Created a chunk of size 119, which is longer than the specified 100
# Created a chunk of size 140, which is longer than the specified 100
# Created a chunk of size 111, which is longer than the specified 100
# Created a chunk of size 130, which is longer than the specified 100
# Created a chunk of size 142, which is longer than the specified 100
# Created a chunk of size 107, which is longer than the specified 100
# Created a chunk of size 184, which is longer than the specified 100
# Created a chunk of size 168, which is longer than the specified 100
# Created a chunk of size 101, which is longer than the specified 100
# Created a chunk of size 127, which is longer than the specified 100
# Created a chunk of size 281, which is longer than the specified 100
# Created a chunk of size 164, which is longer than the specified 100
# Created a chunk of size 178, which is longer than the specified 100
# Created a chunk of size 169, which is longer than the specified 100
# Created a chunk of size 106, which is longer than the specified 100
# Created a chunk of size 109, which is longer than the specified 100
# Created a chunk of size 113, which is longer than the specified 100
# Created a chunk of size 201, which is longer than the specified 100
# Created a chunk of size 250, which is longer than the specified 100
# Created a chunk of size 139, which is longer than the specified 100
# Created a chunk of size 192, which is longer than the specified 100
# Created a chunk of size 325, which is longer than the specified 100
# Created a chunk of size 107, which is longer than the specified 100
# Created a chunk of size 123, which is longer than the specified 100
# Created a chunk of size 132, which is longer than the specified 100
# Created a chunk of size 132, which is longer than the specified 100
# Created a chunk of size 147, which is longer than the specified 100
# Created a chunk of size 111, which is longer than the specified 100
# Created a chunk of size 101, which is longer than the specified 100
# Created a chunk of size 127, which is longer than the specified 100
# Created a chunk of size 120, which is longer than the specified 100
# Created a chunk of size 176, which is longer than the specified 100
# Created a chunk of size 177, which is longer than the specified 100
# Created a chunk of size 177, which is longer than the specified 100
# Created a chunk of size 242, which is longer than the specified 100
# Created a chunk of size 183, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 181, which is longer than the specified 100
# Created a chunk of size 137, which is longer than the specified 100
# Created a chunk of size 125, which is longer than the specified 100
# Created a chunk of size 107, which is longer than the specified 100
# Created a chunk of size 123, which is longer than the specified 100
# Created a chunk of size 110, which is longer than the specified 100
# Created a chunk of size 182, which is longer than the specified 100
# Created a chunk of size 152, which is longer than the specified 100
# Created a chunk of size 162, which is longer than the specified 100
# Created a chunk of size 146, which is longer than the specified 100
# Created a chunk of size 135, which is longer than the specified 100
# Created a chunk of size 153, which is longer than the specified 100
# Created a chunk of size 114, which is longer than the specified 100
# Created a chunk of size 140, which is longer than the specified 100
# Created a chunk of size 114, which is longer than the specified 100
# Created a chunk of size 109, which is longer than the specified 100
# Created a chunk of size 186, which is longer than the specified 100
# Created a chunk of size 123, which is longer than the specified 100
# Created a chunk of size 146, which is longer than the specified 100
# Created a chunk of size 101, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 132, which is longer than the specified 100
# Created a chunk of size 107, which is longer than the specified 100
# Created a chunk of size 103, which is longer than the specified 100
# Created a chunk of size 102, which is longer than the specified 100
# [Document(page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.', metadata={'start_index': 0}),
#  Document(page_content='Last year COVID-19 kept us apart. This year we are finally together again.', metadata={'start_index': 166}),
#  Document(page_content='Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.', metadata={'start_index': 243}),
#  Document(page_content='With a duty to one another to the American people to the Constitution.', metadata={'start_index': 340}),
#  Document(page_content='And with an unwavering resolve that freedom will always triumph over tyranny.', metadata={'start_index': 413}),
#  Document(page_content='Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.', metadata={'start_index': 493}),
#  Document(page_content='He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.', metadata={'start_index': 664}),
#  Document(page_content='He met the Ukrainian people.', metadata={'start_index': 788}),
#  Document(page_content='From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.', metadata={'start_index': 819}),
#  Document(page_content='Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.', metadata={'start_index': 942}),
#  Document(page_content='In this struggle as President Zelenskyy said in his speech to the European Parliament “Light will win over darkness.” The Ukrainian Ambassador to the United States is here tonight.', metadata={'start_index': 1083}),
#  Document(page_content='Let each of us here tonight in this Chamber send an unmistakable signal to Ukraine and to the world.', metadata={'start_index': 1266}),
#  Document(page_content='Please rise if you are able and show that, Yes, we the United States of America stand with the Ukrainian people.', metadata={'start_index': 1369}),
#  Document(page_content='Throughout our history we’ve learned this lesson when dictators do not pay a price for their aggression they cause more chaos.', metadata={'start_index': 1484}),
#  Document(page_content='They keep moving.   \n\nAnd the costs and the threats to America and the world keep rising.', metadata={'start_index': 1615}),
#  Document(page_content='That’s why the NATO Alliance was created to secure peace and stability in Europe after World War 2.', metadata={'start_index': 1709}),
#  Document(page_content='The United States is a member along with 29 other nations.', metadata={'start_index': 1811}),
#  Document(page_content='It matters. American diplomacy matters. American resolve matters.', metadata={'start_index': 1872}),
#  Document(page_content='Putin’s latest attack on Ukraine was premeditated and unprovoked.', metadata={'start_index': 1940}),
#  Document(page_content='He rejected repeated efforts at diplomacy.', metadata={'start_index': 2008}),
#  Document(page_content='He thought the West and NATO wouldn’t respond. And he thought he could divide us at home. Putin was wrong. We were ready.  Here is what we did.', metadata={'start_index': 2053}),
#  Document(page_content='We prepared extensively and carefully.', metadata={'start_index': 2201}),
#  Document(page_content='We spent months building a coalition of other freedom-loving nations from Europe and the Americas to Asia and Africa to confront Putin.', metadata={'start_index': 2242}),
#  Document(page_content='I spent countless hours unifying our European allies. We shared with the world in advance what we knew Putin was planning and precisely how he would try to falsely justify his aggression.', metadata={'start_index': 2380}),
#  Document(page_content='We countered Russia’s lies with truth.', metadata={'start_index': 2571}),
#  Document(page_content='And now that he has acted the free world is holding him accountable.', metadata={'start_index': 2614}),
#  Document(page_content='Along with twenty-seven members of the European Union including France, Germany, Italy, as well as countries like the United Kingdom, Canada, Japan, Korea, Australia, New Zealand, and many others, even Switzerland.', metadata={'start_index': 2685}),
#  Document(page_content='We are inflicting pain on Russia and supporting the people of Ukraine. Putin is now isolated from the world more than ever.', metadata={'start_index': 2902}),
#  Document(page_content='Together with our allies –we are right now enforcing powerful economic sanctions.', metadata={'start_index': 3028}),
#  Document(page_content='We are cutting off Russia’s largest banks from the international financial system.', metadata={'start_index': 3112}),
#  Document(page_content='Preventing Russia’s central bank from defending the Russian Ruble making Putin’s $630 Billion “war fund” worthless.', metadata={'start_index': 3198}),
#  Document(page_content='We are choking off Russia’s access to technology that will sap its economic strength and weaken its military for years to come.', metadata={'start_index': 3318}),
#  Document(page_content='Tonight I say to the Russian oligarchs and corrupt leaders who have bilked billions of dollars off this violent regime no more.', metadata={'start_index': 3449}),
#  Document(page_content='The U.S. Department of Justice is assembling a dedicated task force to go after the crimes of Russian oligarchs.', metadata={'start_index': 3579}),
#  Document(page_content='We are joining with our European allies to find and seize your yachts your luxury apartments your private jets. We are coming for your ill-begotten gains.', metadata={'start_index': 3695}),
#  Document(page_content='And tonight I am announcing that we will join our allies in closing off American air space to all Russian flights – further isolating Russia – and adding an additional squeeze –on their economy. The Ruble has lost 30% of its value.', metadata={'start_index': 3852}),
#  Document(page_content='The Russian stock market has lost 40% of its value and trading remains suspended. Russia’s economy is reeling and Putin alone is to blame.', metadata={'start_index': 4086}),
#  Document(page_content='Together with our allies we are providing support to the Ukrainians in their fight for freedom. Military assistance. Economic assistance. Humanitarian assistance.', metadata={'start_index': 4227}),
#  Document(page_content='We are giving more than $1 Billion in direct assistance to Ukraine.', metadata={'start_index': 4392}),
#  Document(page_content='And we will continue to aid the Ukrainian people as they defend their country and to help ease their suffering.', metadata={'start_index': 4462}),
#  Document(page_content='Let me be clear, our forces are not engaged and will not engage in conflict with Russian forces in Ukraine.', metadata={'start_index': 4577}),
#  Document(page_content='Our forces are not going to Europe to fight in Ukraine, but to defend our NATO Allies – in the event that Putin decides to keep moving west.', metadata={'start_index': 4688}),
#  Document(page_content='For that purpose we’ve mobilized American ground forces, air squadrons, and ship deployments to protect NATO countries including Poland, Romania, Latvia, Lithuania, and Estonia.', metadata={'start_index': 4832}),
#  Document(page_content='As I have made crystal clear the United States and our Allies will defend every inch of territory of NATO countries with the full force of our collective power.', metadata={'start_index': 5012}),
#  Document(page_content='And we remain clear-eyed. The Ukrainians are fighting back with pure courage. But the next few days weeks, months, will be hard on them.', metadata={'start_index': 5176}),
#  Document(page_content='Putin has unleashed violence and chaos.  But while he may make gains on the battlefield – he will pay a continuing high price over the long run.', metadata={'start_index': 5316}),
#  Document(page_content='And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.', metadata={'start_index': 5463}),
#  Document(page_content='To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.', metadata={'start_index': 5638}),
#  Document(page_content='And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.', metadata={'start_index': 5786}),
#  Document(page_content='Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.', metadata={'start_index': 5978}),
#  Document(page_content='America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.', metadata={'start_index': 6132}),
#  Document(page_content='These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.', metadata={'start_index': 6306}),
#  Document(page_content='But I want you to know that we are going to be okay.', metadata={'start_index': 6423}),
#  Document(page_content='When the history of this era is written Putin’s war on Ukraine will have left Russia weaker and the rest of the world stronger.', metadata={'start_index': 6478}),
#  Document(page_content='While it shouldn’t have taken something so terrible for people around the world to see what’s at stake now everyone sees it clearly.', metadata={'start_index': 6608}),
#  Document(page_content='We see the unity among leaders of nations and a more unified Europe a more unified West. And we see unity among the people who are gathering in cities in large crowds around the world even in Russia to demonstrate their support for Ukraine.', metadata={'start_index': 6743}),
#  Document(page_content='In the battle between democracy and autocracy, democracies are rising to the moment, and the world is clearly choosing the side of peace and security.', metadata={'start_index': 6987}),
#  Document(page_content='This is a real test. It’s going to take time. So let us continue to draw inspiration from the iron will of the Ukrainian people.', metadata={'start_index': 7140}),
#  Document(page_content='To our fellow Ukrainian Americans who forge a deep bond that connects our two nations we stand with you.', metadata={'start_index': 7271}),
#  Document(page_content='Putin may circle Kyiv with tanks, but he will never gain the hearts and souls of the Ukrainian people.', metadata={'start_index': 7378}),
#  Document(page_content='He will never extinguish their love of freedom. He will never weaken the resolve of the free world.', metadata={'start_index': 7483}),
#  Document(page_content='We meet tonight in an America that has lived through two of the hardest years this nation has ever faced.', metadata={'start_index': 7585}),
#  Document(page_content='The pandemic has been punishing.', metadata={'start_index': 7693}),
#  Document(page_content='And so many families are living paycheck to paycheck, struggling to keep up with the rising cost of food, gas, housing, and so much more.', metadata={'start_index': 7728}),
#  Document(page_content='I understand.', metadata={'start_index': 7868}),
#  Document(page_content='I remember when my Dad had to leave our home in Scranton, Pennsylvania to find work. I grew up in a family where if the price of food went up, you felt it.', metadata={'start_index': 7884}),
#  Document(page_content='That’s why one of the first things I did as President was fight to pass the American Rescue Plan.', metadata={'start_index': 8042}),
#  Document(page_content='Because people were hurting. We needed to act, and we did.', metadata={'start_index': 8143}),
#  Document(page_content='Few pieces of legislation have done more in a critical moment in our history to lift us out of crisis.', metadata={'start_index': 8204}),
#  Document(page_content='It fueled our efforts to vaccinate the nation and combat COVID-19. It delivered immediate economic relief for tens of millions of Americans.', metadata={'start_index': 8309}),
#  Document(page_content='Helped put food on their table, keep a roof over their heads, and cut the cost of health insurance.', metadata={'start_index': 8453}),
#  Document(page_content='And as my Dad used to say, it gave people a little breathing room.', metadata={'start_index': 8555}),
#  Document(page_content='And unlike the $2 Trillion tax cut passed in the previous administration that benefitted the top 1% of Americans, the American Rescue Plan helped working people—and left no one behind.', metadata={'start_index': 8624}),
#  Document(page_content='And it worked. It created jobs. Lots of jobs.', metadata={'start_index': 8811}),
#  Document(page_content='In fact—our economy created over 6.5 Million new jobs just last year, more jobs created in one year  \nthan ever before in the history of America.', metadata={'start_index': 8859}),
#  Document(page_content='Our economy grew at a rate of 5.7% last year, the strongest growth in nearly 40 years, the first step in bringing fundamental change to an economy that hasn’t worked for the working people of this nation for too long.', metadata={'start_index': 9007}),
#  Document(page_content='For the past 40 years we were told that if we gave tax breaks to those at the very top, the benefits would trickle down to everyone else.', metadata={'start_index': 9228}),
#  Document(page_content='But that trickle-down theory led to weaker economic growth, lower wages, bigger deficits, and the widest gap between those at the top and everyone else in nearly a century.', metadata={'start_index': 9368}),
#  Document(page_content='Vice President Harris and I ran for office with a new economic vision for America.', metadata={'start_index': 9543}),
#  Document(page_content='Invest in America. Educate Americans. Grow the workforce. Build the economy from the bottom up  \nand the middle out, not from the top down.', metadata={'start_index': 9628}),
#  Document(page_content='Because we know that when the middle class grows, the poor have a ladder up and the wealthy do very well.', metadata={'start_index': 9771}),
#  Document(page_content='America used to have the best roads, bridges, and airports on Earth.', metadata={'start_index': 9879}),
#  Document(page_content='Now our infrastructure is ranked 13th in the world.', metadata={'start_index': 9950}),
#  Document(page_content='We won’t be able to compete for the jobs of the 21st Century if we don’t fix that.', metadata={'start_index': 10004}),
#  Document(page_content='That’s why it was so important to pass the Bipartisan Infrastructure Law—the most sweeping investment to rebuild America in history.', metadata={'start_index': 10089}),
#  Document(page_content='This was a bipartisan effort, and I want to thank the members of both parties who worked to make it happen.', metadata={'start_index': 10224}),
#  Document(page_content='We’re done talking about infrastructure weeks. \n\nWe’re going to have an infrastructure decade.', metadata={'start_index': 10334}),
#  Document(page_content='It is going to transform America and put us on a path to win the economic competition of the 21st Century that we face with the rest of the world—particularly with China.', metadata={'start_index': 10431}),
#  Document(page_content='As I’ve told Xi Jinping, it is never a good bet to bet against the American people.', metadata={'start_index': 10605}),
#  Document(page_content='We’ll create good jobs for millions of Americans, modernizing roads, airports, ports, and waterways all across America.', metadata={'start_index': 10691}),
#  Document(page_content='And we’ll do it all to withstand the devastating effects of the climate crisis and promote environmental justice.', metadata={'start_index': 10813}),
#  Document(page_content='We’ll build a national network of 500,000 electric vehicle charging stations, begin to replace poisonous lead pipes—so every child—and every American—has clean water to drink at home and at school, provide affordable high-speed internet for every American—urban, suburban, rural, and tribal communities.', metadata={'start_index': 10929}),
#  Document(page_content='4,000 projects have already been announced.', metadata={'start_index': 11235}),
#  Document(page_content='And tonight, I’m announcing that this year we will start fixing over 65,000 miles of highway and 1,500 bridges in disrepair.', metadata={'start_index': 11281}),
#  Document(page_content='When we use taxpayer dollars to rebuild America – we are going to Buy American: buy American products to support American jobs.', metadata={'start_index': 11408}),
#  Document(page_content='The federal government spends about $600 Billion a year to keep the country safe and secure.', metadata={'start_index': 11538}),
#  Document(page_content='There’s been a law on the books for almost a century \nto make sure taxpayers’ dollars support American jobs and businesses.', metadata={'start_index': 11633}),
#  Document(page_content='Every Administration says they’ll do it, but we are actually doing it.', metadata={'start_index': 11759}),
#  Document(page_content='We will buy American to make sure everything from the deck of an aircraft carrier to the steel on highway guardrails are made in America.', metadata={'start_index': 11832}),
#  Document(page_content='But to compete for the best jobs of the future, we also need to level the playing field with China and other competitors.', metadata={'start_index': 11972}),
#  Document(page_content='That’s why it is so important to pass the Bipartisan Innovation Act sitting in Congress that will make record investments in emerging technologies and American manufacturing.', metadata={'start_index': 12096}),
#  Document(page_content='Let me give you one example of why it’s so important to pass it.', metadata={'start_index': 12273}),
#  Document(page_content='If you travel 20 miles east of Columbus, Ohio, you’ll find 1,000 empty acres of land.', metadata={'start_index': 12340}),
#  Document(page_content='It won’t look like much, but if you stop and look closely, you’ll see a “Field of dreams,” the ground on which America’s future will be built.', metadata={'start_index': 12428}),
#  Document(page_content='This is where Intel, the American company that helped build Silicon Valley, is going to build its $20 billion semiconductor “mega site”.', metadata={'start_index': 12573}),
#  Document(page_content='Up to eight state-of-the-art factories in one place. 10,000 new good-paying jobs.', metadata={'start_index': 12712}),
#  Document(page_content='Some of the most sophisticated manufacturing in the world to make computer chips the size of a fingertip that power the world and our everyday lives.', metadata={'start_index': 12796}),
#  Document(page_content='Smartphones. The Internet. Technology we have yet to invent. \n\nBut that’s just the beginning.', metadata={'start_index': 12948}),
#  Document(page_content='Intel’s CEO, Pat Gelsinger, who is here tonight, told me they are ready to increase their investment from  \n$20 billion to $100 billion.', metadata={'start_index': 13044}),
#  Document(page_content='That would be one of the biggest investments in manufacturing in American history.', metadata={'start_index': 13183}),
#  Document(page_content='And all they’re waiting for is for you to pass this bill.', metadata={'start_index': 13268}),
#  Document(page_content='So let’s not wait any longer. Send it to my desk. I’ll sign it.  \n\nAnd we will really take off.', metadata={'start_index': 13328}),
#  Document(page_content='And Intel is not alone. \n\nThere’s something happening in America.', metadata={'start_index': 13426}),
#  Document(page_content='Just look around and you’ll see an amazing story.', metadata={'start_index': 13494}),
#  Document(page_content='The rebirth of the pride that comes from stamping products “Made In America.” The revitalization of American manufacturing.', metadata={'start_index': 13546}),
#  Document(page_content='Companies are choosing to build new factories here, when just a few years ago, they would have built them overseas.', metadata={'start_index': 13674}),
#  Document(page_content='That’s what is happening. Ford is investing $11 billion to build electric vehicles, creating 11,000 jobs across the country.', metadata={'start_index': 13792}),
#  Document(page_content='GM is making the largest investment in its history—$7 billion to build electric vehicles, creating 4,000 jobs in Michigan.', metadata={'start_index': 13919}),
#  Document(page_content='All told, we created 369,000 new manufacturing jobs in America just last year.', metadata={'start_index': 14044}),
#  Document(page_content='Powered by people I’ve met like JoJo Burgess, from generations of union steelworkers from Pittsburgh, who’s here with us tonight.', metadata={'start_index': 14125}),
#  Document(page_content='As Ohio Senator Sherrod Brown says, “It’s time to bury the label “Rust Belt.” \n\nIt’s time.', metadata={'start_index': 14257}),
#  Document(page_content='But with all the bright spots in our economy, record job growth and higher wages, too many families are struggling to keep up with the bills.', metadata={'start_index': 14350}),
#  Document(page_content='Inflation is robbing them of the gains they might otherwise feel.', metadata={'start_index': 14495}),
#  Document(page_content='I get it. That’s why my top priority is getting prices under control.', metadata={'start_index': 14563}),
#  Document(page_content='Look, our economy roared back faster than most predicted, but the pandemic meant that businesses had a hard time hiring enough workers to keep up production in their factories.', metadata={'start_index': 14635}),
#  Document(page_content='The pandemic also disrupted global supply chains.', metadata={'start_index': 14814}),
#  Document(page_content='When factories close, it takes longer to make goods and get them from the warehouse to the store, and prices go up.', metadata={'start_index': 14866}),
#  Document(page_content='Look at cars.', metadata={'start_index': 14984}),
#  Document(page_content='Last year, there weren’t enough semiconductors to make all the cars that people wanted to buy.', metadata={'start_index': 15000}),
#  Document(page_content='And guess what, prices of automobiles went up. \n\nSo—we have a choice.', metadata={'start_index': 15097}),
#  Document(page_content='One way to fight inflation is to drive down wages and make Americans poorer.', metadata={'start_index': 15169}),
#  Document(page_content='I have a better plan to fight inflation. \n\nLower your costs, not your wages.', metadata={'start_index': 15249}),
#  Document(page_content='Make more cars and semiconductors in America. \n\nMore infrastructure and innovation in America.', metadata={'start_index': 15328}),
#  Document(page_content='More goods moving faster and cheaper in America.', metadata={'start_index': 15425}),
#  Document(page_content='More jobs where you can earn a good living in America.', metadata={'start_index': 15476}),
#  Document(page_content='And instead of relying on foreign supply chains, let’s make it in America.', metadata={'start_index': 15533}),
#  Document(page_content='Economists call it “increasing the productive capacity of our economy.”', metadata={'start_index': 15610}),
#  Document(page_content='I call it building a better America.', metadata={'start_index': 15684}),
#  Document(page_content='My plan to fight inflation will lower your costs and lower the deficit.', metadata={'start_index': 15723}),
#  Document(page_content='17 Nobel laureates in economics say my plan will ease long-term inflationary pressures. Top business leaders and most Americans support my plan. And here’s the plan:', metadata={'start_index': 15797}),
#  Document(page_content='First – cut the cost of prescription drugs. Just look at insulin. One in ten Americans has diabetes. In Virginia, I met a 13-year-old boy named Joshua Davis.', metadata={'start_index': 15965}),
#  Document(page_content='He and his Dad both have Type 1 diabetes, which means they need insulin every day. Insulin costs about $10 a vial to make.', metadata={'start_index': 16126}),
#  Document(page_content='But drug companies charge families like Joshua and his Dad up to 30 times more. I spoke with Joshua’s mom.', metadata={'start_index': 16252}),
#  Document(page_content='Imagine what it’s like to look at your child who needs insulin and have no idea how you’re going to pay for it.', metadata={'start_index': 16361}),
#  Document(page_content='What it does to your dignity, your ability to look your child in the eye, to be the parent you expect to be.', metadata={'start_index': 16476}),
#  Document(page_content='Joshua is here with us tonight. Yesterday was his birthday. Happy birthday, buddy.', metadata={'start_index': 16587}),
#  Document(page_content='For Joshua, and for the 200,000 other young people with Type 1 diabetes, let’s cap the cost of insulin at $35 a month so everyone can afford it.', metadata={'start_index': 16673}),
#  Document(page_content='Drug companies will still do very well. And while we’re at it let Medicare negotiate lower prices for prescription drugs, like the VA already does.', metadata={'start_index': 16821}),
#  Document(page_content='Look, the American Rescue Plan is helping millions of families on Affordable Care Act plans save $2,400 a year on their health care premiums. Let’s close the coverage gap and make those savings permanent.', metadata={'start_index': 16971}),
#  Document(page_content='Second – cut energy costs for families an average of $500 a year by combatting climate change.', metadata={'start_index': 17178}),
#  Document(page_content='Let’s provide investments and tax credits to weatherize your homes and businesses to be energy efficient and you get a tax credit; double America’s clean energy production in solar, wind, and so much more;  lower the price of electric vehicles, saving you another $80 a month because you’ll never have to pay at the gas pump again.', metadata={'start_index': 17276}),
#  Document(page_content='Third – cut the cost of child care. Many families pay up to $14,000 a year for child care per child.', metadata={'start_index': 17610}),
#  Document(page_content='Middle-class and working families shouldn’t have to pay more than 7% of their income for care of young children.', metadata={'start_index': 17714}),
#  Document(page_content='My plan will cut the cost in half for most families and help parents, including millions of women, who left the workforce during the pandemic because they couldn’t afford child care, to be able to get back to work.', metadata={'start_index': 17830}),
#  Document(page_content='My plan doesn’t stop there. It also includes home and long-term care. More affordable housing. And Pre-K for every 3- and 4-year-old.', metadata={'start_index': 18047}),
#  Document(page_content='All of these will lower costs.', metadata={'start_index': 18184}),
#  Document(page_content='And under my plan, nobody earning less than $400,000 a year will pay an additional penny in new taxes. Nobody.', metadata={'start_index': 18217}),
#  Document(page_content='The one thing all Americans agree on is that the tax system is not fair. We have to fix it.', metadata={'start_index': 18331}),
#  Document(page_content='I’m not looking to punish anyone. But let’s make sure corporations and the wealthiest Americans start paying their fair share.', metadata={'start_index': 18426}),
#  Document(page_content='Just last year, 55 Fortune 500 corporations earned $40 billion in profits and paid zero dollars in federal income tax.', metadata={'start_index': 18555}),
#  Document(page_content='That’s simply not fair. That’s why I’ve proposed a 15% minimum tax rate for corporations.', metadata={'start_index': 18677}),
#  Document(page_content='We got more than 130 countries to agree on a global minimum tax rate so companies can’t get out of paying their taxes at home by shipping jobs and factories overseas.', metadata={'start_index': 18769}),
#  Document(page_content='That’s why I’ve proposed closing loopholes so the very wealthy don’t pay a lower tax rate than a teacher or a firefighter.', metadata={'start_index': 18938}),
#  Document(page_content='So that’s my plan. It will grow the economy and lower costs for families.', metadata={'start_index': 19064}),
#  Document(page_content='So what are we waiting for? Let’s get this done. And while you’re at it, confirm my nominees to the Federal Reserve, which plays a critical role in fighting inflation.', metadata={'start_index': 19140}),
#  Document(page_content='My plan will not only lower costs to give families a fair shot, it will lower the deficit.', metadata={'start_index': 19311}),
#  Document(page_content='The previous Administration not only ballooned the deficit with tax cuts for the very wealthy and corporations, it undermined the watchdogs whose job was to keep pandemic relief funds from being wasted.', metadata={'start_index': 19404}),
#  Document(page_content='But in my administration, the watchdogs have been welcomed back.', metadata={'start_index': 19609}),
#  Document(page_content='We’re going after the criminals who stole billions in relief money meant for small businesses and millions of Americans.', metadata={'start_index': 19676}),
#  Document(page_content='And tonight, I’m announcing that the Justice Department will name a chief prosecutor for pandemic fraud.', metadata={'start_index': 19800}),
#  Document(page_content='By the end of this year, the deficit will be down to less than half what it was before I took office.', metadata={'start_index': 19907}),
#  Document(page_content='The only president ever to cut the deficit by more than one trillion dollars in a single year.', metadata={'start_index': 20012}),
#  Document(page_content='Lowering your costs also means demanding more competition.', metadata={'start_index': 20109}),
#  Document(page_content='I’m a capitalist, but capitalism without competition isn’t capitalism.', metadata={'start_index': 20170}),
#  Document(page_content='It’s exploitation—and it drives up prices.', metadata={'start_index': 20243}),
#  Document(page_content='When corporations don’t have to compete, their profits go up, your prices go up, and small businesses and family farmers and ranchers go under.', metadata={'start_index': 20288}),
#  Document(page_content='We see it happening with ocean carriers moving goods in and out of America.', metadata={'start_index': 20434}),
#  Document(page_content='During the pandemic, these foreign-owned companies raised prices by as much as 1,000% and made record profits.', metadata={'start_index': 20512}),
#  Document(page_content='Tonight, I’m announcing a crackdown on these companies overcharging American businesses and consumers.', metadata={'start_index': 20625}),
#  Document(page_content='And as Wall Street firms take over more nursing homes, quality in those homes has gone down and costs have gone up.', metadata={'start_index': 20730}),
#  Document(page_content='That ends on my watch.', metadata={'start_index': 20849}),
#  Document(page_content='Medicare is going to set higher standards for nursing homes and make sure your loved ones get the care they deserve and expect.', metadata={'start_index': 20874}),
#  Document(page_content='We’ll also cut costs and keep the economy going strong by giving workers a fair shot, provide more training and apprenticeships, hire them based on their skills not degrees.', metadata={'start_index': 21004}),
#  Document(page_content='Let’s pass the Paycheck Fairness Act and paid leave.', metadata={'start_index': 21180}),
#  Document(page_content='Raise the minimum wage to $15 an hour and extend the Child Tax Credit, so no one has to raise a family in poverty.', metadata={'start_index': 21236}),
#  Document(page_content='Let’s increase Pell Grants and increase our historic support of HBCUs, and invest in what Jill—our First Lady who teaches full-time—calls America’s best-kept secret: community colleges.', metadata={'start_index': 21353}),
#  Document(page_content='And let’s pass the PRO Act when a majority of workers want to form a union—they shouldn’t be stopped.', metadata={'start_index': 21541}),
#  Document(page_content='When we invest in our workers, when we build the economy from the bottom up and the middle out together, we can do something we haven’t done in a long time: build a better America.', metadata={'start_index': 21646}),
#  Document(page_content='For more than two years, COVID-19 has impacted every decision in our lives and the life of the nation.', metadata={'start_index': 21829}),
#  Document(page_content='And I know you’re tired, frustrated, and exhausted. \n\nBut I also know this.', metadata={'start_index': 21934}),
#  Document(page_content='Because of the progress we’ve made, because of your resilience and the tools we have, tonight I can say  \nwe are moving forward safely, back to more normal routines.', metadata={'start_index': 22012}),
#  Document(page_content='We’ve reached a new moment in the fight against COVID-19, with severe cases down to a level not seen since last July.', metadata={'start_index': 22181}),
#  Document(page_content='Just a few days ago, the Centers for Disease Control and Prevention—the CDC—issued new mask guidelines.', metadata={'start_index': 22302}),
#  Document(page_content='Under these new guidelines, most Americans in most of the country can now be mask free.', metadata={'start_index': 22408}),
#  Document(page_content='And based on the projections, more of the country will reach that point across the next couple of weeks.', metadata={'start_index': 22500}),
#  Document(page_content='Thanks to the progress we have made this past year, COVID-19 need no longer control our lives.', metadata={'start_index': 22607}),
#  Document(page_content='I know some are talking about “living with COVID-19”. Tonight – I say that we will never just accept living with COVID-19.', metadata={'start_index': 22705}),
#  Document(page_content='We will continue to combat the virus as we do other diseases. And because this is a virus that mutates and spreads, we will stay on guard.', metadata={'start_index': 22830}),
#  Document(page_content='Here are four common sense steps as we move forward safely.', metadata={'start_index': 22971}),
# ...
#  Document(page_content='And I ask Congress to pass proven measures to reduce gun violence. Pass universal background checks. Why should anyone on a terrorist list be able to purchase a weapon?', metadata={'start_index': 28235}),
#  Document(page_content='Ban assault weapons and high-capacity magazines.', metadata={'start_index': 28406}),
#  Document(page_content='Repeal the liability shield that makes gun manufacturers the only industry in America that can’t be sued.', metadata={'start_index': 28457}),
#  Document(page_content='These laws don’t infringe on the Second Amendment. They save lives.', metadata={'start_index': 28565}),
#  Document(page_content='The most fundamental right in America is the right to vote – and to have it counted. And it’s under assault.', metadata={'start_index': 28635}),
#  Document(page_content='In state after state, new laws have been passed, not only to suppress the vote, but to subvert entire elections.', metadata={'start_index': 28746}),
#  Document(page_content='We cannot let this happen.', metadata={'start_index': 28861}),
#  Document(page_content='Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.', metadata={'start_index': 28890}),
#  Document(page_content='Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.', metadata={'start_index': 29093}),
#  Document(page_content='One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.', metadata={'start_index': 29345}),
#  Document(page_content='And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.', metadata={'start_index': 29486}),
#  Document(page_content='A former top litigator in private practice. A former federal public defender. And from a family of public school educators and police officers. A consensus builder. Since she’s been nominated, she’s received a broad range of support—from the Fraternal Order of Police to former judges appointed by Democrats and Republicans.', metadata={'start_index': 29680}),
#  Document(page_content='And if we are to advance liberty and justice, we need to secure the Border and fix the immigration system.', metadata={'start_index': 30007}),
#  Document(page_content='We can do both. At our border, we’ve installed new technology like cutting-edge scanners to better detect drug smuggling.', metadata={'start_index': 30116}),
#  Document(page_content='We’ve set up joint patrols with Mexico and Guatemala to catch more human traffickers.', metadata={'start_index': 30241}),
#  Document(page_content='We’re putting in place dedicated immigration judges so families fleeing persecution and violence can have their cases heard faster.', metadata={'start_index': 30330}),
#  Document(page_content='We’re securing commitments and supporting partners in South and Central America to host more refugees and secure their own borders.', metadata={'start_index': 30464}),
#  Document(page_content='We can do all this while keeping lit the torch of liberty that has led generations of immigrants to this land—my forefathers and so many of yours.', metadata={'start_index': 30598}),
#  Document(page_content='Provide a pathway to citizenship for Dreamers, those on temporary status, farm workers, and essential workers.', metadata={'start_index': 30747}),
#  Document(page_content='Revise our laws so businesses have the workers they need and families don’t wait decades to reunite.', metadata={'start_index': 30860}),
#  Document(page_content='It’s not only the right thing to do—it’s the economically smart thing to do.', metadata={'start_index': 30963}),
#  Document(page_content='That’s why immigration reform is supported by everyone from labor unions to religious leaders to the U.S. Chamber of Commerce.', metadata={'start_index': 31042}),
#  Document(page_content='Let’s get it done once and for all.', metadata={'start_index': 31171}),
#  Document(page_content='Advancing liberty and justice also requires protecting the rights of women.', metadata={'start_index': 31209}),
#  Document(page_content='The constitutional right affirmed in Roe v. Wade—standing precedent for half a century—is under attack as never before.', metadata={'start_index': 31287}),
#  Document(page_content='If we want to go forward—not backward—we must protect access to health care. Preserve a woman’s right to choose. And let’s continue to advance maternal health care in America.', metadata={'start_index': 31409}),
#  Document(page_content='And for our LGBTQ+ Americans, let’s finally get the bipartisan Equality Act to my desk. The onslaught of state laws targeting transgender Americans and their families is wrong.', metadata={'start_index': 31587}),
#  Document(page_content='As I said last year, especially to our younger transgender Americans, I will always have your back as your President, so you can be yourself and reach your God-given potential.', metadata={'start_index': 31766}),
#  Document(page_content='While it often appears that we never agree, that isn’t true. I signed 80 bipartisan bills into law last year. From preventing government shutdowns to protecting Asian-Americans from still-too-common hate crimes to reforming military justice.', metadata={'start_index': 31945}),
#  Document(page_content='And soon, we’ll strengthen the Violence Against Women Act that I first wrote three decades ago. It is important for us to show the nation that we can come together and do big things.', metadata={'start_index': 32189}),
#  Document(page_content='So tonight I’m offering a Unity Agenda for the Nation. Four big things we can do together.', metadata={'start_index': 32374}),
#  Document(page_content='First, beat the opioid epidemic.', metadata={'start_index': 32468}),
#  Document(page_content='There is so much we can do. Increase funding for prevention, treatment, harm reduction, and recovery.', metadata={'start_index': 32503}),
#  Document(page_content='Get rid of outdated rules that stop doctors from prescribing treatments. And stop the flow of illicit drugs by working with state and local law enforcement to go after traffickers.', metadata={'start_index': 32608}),
#  Document(page_content='If you’re suffering from addiction, know you are not alone. I believe in recovery, and I celebrate the 23 million Americans in recovery.', metadata={'start_index': 32791}),
#  Document(page_content='Second, let’s take on mental health. Especially among our children, whose lives and education have been turned upside down.', metadata={'start_index': 32930}),
#  Document(page_content='The American Rescue Plan gave schools money to hire teachers and help students make up for lost learning.', metadata={'start_index': 33057}),
#  Document(page_content='I urge every parent to make sure your school does just that. And we can all play a part—sign up to be a tutor or a mentor.', metadata={'start_index': 33166}),
#  Document(page_content='Children were also struggling before the pandemic. Bullying, violence, trauma, and the harms of social media.', metadata={'start_index': 33291}),
#  Document(page_content='As Frances Haugen, who is here with us tonight, has shown, we must hold social media platforms accountable for the national experiment they’re conducting on our children for profit.', metadata={'start_index': 33403}),
#  Document(page_content='It’s time to strengthen privacy protections, ban targeted advertising to children, demand tech companies stop collecting personal data on our children.', metadata={'start_index': 33587}),
#  Document(page_content='And let’s get all Americans the mental health services they need. More people they can turn to for help, and full parity between physical and mental health care.', metadata={'start_index': 33741}),
#  Document(page_content='Third, support our veterans. \n\nVeterans are the best of us.', metadata={'start_index': 33905}),
#  Document(page_content='I’ve always believed that we have a sacred obligation to equip all those we send to war and care for them and their families when they come home.', metadata={'start_index': 33967}),
#  Document(page_content='My administration is providing assistance with job training and housing, and now helping lower-income veterans get VA care debt-free.', metadata={'start_index': 34115}),
#  Document(page_content='Our troops in Iraq and Afghanistan faced many dangers.', metadata={'start_index': 34252}),
#  Document(page_content='One was stationed at bases and breathing in toxic smoke from “burn pits” that incinerated wastes of war—medical and hazard material, jet fuel, and more.', metadata={'start_index': 34309}),
#  Document(page_content='When they came home, many of the world’s fittest and best trained warriors were never the same.', metadata={'start_index': 34464}),
#  Document(page_content='Headaches. Numbness. Dizziness. \n\nA cancer that would put them in a flag-draped coffin. \n\nI know.', metadata={'start_index': 34562}),
#  Document(page_content='I know. \n\nOne of those soldiers was my son Major Beau Biden.', metadata={'start_index': 34652}),
#  Document(page_content='We don’t know for sure if a burn pit was the cause of his brain cancer, or the diseases of so many of our troops.', metadata={'start_index': 34715}),
#  Document(page_content='But I’m committed to finding out everything we can.', metadata={'start_index': 34831}),
#  Document(page_content='Committed to military families like Danielle Robinson from Ohio.', metadata={'start_index': 34885}),
#  Document(page_content='The widow of Sergeant First Class Heath Robinson.', metadata={'start_index': 34952}),
#  Document(page_content='He was born a soldier. Army National Guard. Combat medic in Kosovo and Iraq.', metadata={'start_index': 35005}),
#  Document(page_content='Stationed near Baghdad, just yards from burn pits the size of football fields.', metadata={'start_index': 35084}),
#  Document(page_content='Heath’s widow Danielle is here with us tonight. They loved going to Ohio State football games. He loved building Legos with their daughter.', metadata={'start_index': 35165}),
#  Document(page_content='But cancer from prolonged exposure to burn pits ravaged Heath’s lungs and body.', metadata={'start_index': 35307}),
#  Document(page_content='Danielle says Heath was a fighter to the very end.', metadata={'start_index': 35389}),
#  Document(page_content='He didn’t know how to stop fighting, and neither did she.', metadata={'start_index': 35442}),
#  Document(page_content='Through her pain she found purpose to demand we do better. \n\nTonight, Danielle—we are.', metadata={'start_index': 35502}),
#  Document(page_content='The VA is pioneering new ways of linking toxic exposures to diseases, already helping more veterans get benefits.', metadata={'start_index': 35591}),
#  Document(page_content='And tonight, I’m announcing we’re expanding eligibility to veterans suffering from nine respiratory cancers.', metadata={'start_index': 35707}),
#  Document(page_content='I’m also calling on Congress: pass a law to make sure veterans devastated by toxic exposures in Iraq and Afghanistan finally get the benefits and comprehensive health care they deserve.', metadata={'start_index': 35818}),
#  Document(page_content='And fourth, let’s end cancer as we know it.', metadata={'start_index': 36006}),
#  Document(page_content='This is personal to me and Jill, to Kamala, and to so many of you.', metadata={'start_index': 36052}),
#  Document(page_content='Cancer is the #2 cause of death in America–second only to heart disease.', metadata={'start_index': 36121}),
#  Document(page_content='Last month, I announced our plan to supercharge  \nthe Cancer Moonshot that President Obama asked me to lead six years ago.', metadata={'start_index': 36196}),
#  Document(page_content='Our goal is to cut the cancer death rate by at least 50% over the next 25 years, turn more cancers from death sentences into treatable diseases.', metadata={'start_index': 36321}),
#  Document(page_content='More support for patients and families.', metadata={'start_index': 36469}),
#  Document(page_content='To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.', metadata={'start_index': 36511}),
#  Document(page_content='It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.', metadata={'start_index': 36612}),
#  Document(page_content='ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.', metadata={'start_index': 36715}),
#  Document(page_content='A unity agenda for the nation. \n\nWe can do this.', metadata={'start_index': 36820}),
#  Document(page_content='My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.', metadata={'start_index': 36871}),
#  Document(page_content='In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.', metadata={'start_index': 36968}),
#  Document(page_content='We have fought for freedom, expanded liberty, defeated totalitarianism and terror.', metadata={'start_index': 37102}),
#  Document(page_content='And built the strongest, freest, and most prosperous nation the world has ever known.', metadata={'start_index': 37187}),
#  Document(page_content='Now is the hour. \n\nOur moment of responsibility.', metadata={'start_index': 37275}),
#  Document(page_content='Our test of resolve and conscience, of history itself.', metadata={'start_index': 37326}),
#  Document(page_content='It is in this moment that our character is formed. Our purpose is found. Our future is forged.', metadata={'start_index': 37383}),
#  Document(page_content='Well I know this nation.  \n\nWe will meet the test.', metadata={'start_index': 37480}),
#  Document(page_content='To protect freedom and liberty, to expand fairness and opportunity. \n\nWe will save democracy.', metadata={'start_index': 37533}),
#  Document(page_content='As hard as these times have been, I am more optimistic about America today than I have been my whole life.', metadata={'start_index': 37629}),
#  Document(page_content='Because I see the future that is within our grasp.', metadata={'start_index': 37738}),
#  Document(page_content='Because I know there is simply nothing beyond our capacity.', metadata={'start_index': 37791}),
#  Document(page_content='We are the only nation on Earth that has always turned every crisis we have faced into an opportunity.', metadata={'start_index': 37853}),
#  Document(page_content='The only nation that can be defined by a single word: possibilities.', metadata={'start_index': 37958}),
#  Document(page_content='So on this night, in our 245th year as a nation, I have come to report on the State of the Union.', metadata={'start_index': 38029}),
#  Document(page_content='And my report is this: the State of the Union is strong—because you, the American people, are strong.', metadata={'start_index': 38129}),
#  Document(page_content='We are stronger today than we were a year ago.', metadata={'start_index': 38233}),
#  Document(page_content='And we will be stronger a year from now than we are today.', metadata={'start_index': 38282}),
#  Document(page_content='Now is our moment to meet and overcome the challenges of our time. \n\nAnd we will, as one people.', metadata={'start_index': 38343}),
#  Document(page_content='One America. \n\nThe United States of America. \n\nMay God bless you all. May God protect our troops.', metadata={'start_index': 38442})]

# %%
from langchain.text_splitter import (
    RecursiveCharacterTextSplitter,
    Language,
)

# %%
[e.value for e in Language]
# Out:
# ['cpp',
#  'go',
#  'java',
#  'kotlin',
#  'js',
#  'ts',
#  'php',
#  'proto',
#  'python',
#  'rst',
#  'ruby',
#  'rust',
#  'scala',
#  'swift',
#  'markdown',
#  'latex',
#  'html',
#  'sol',
#  'csharp',
#  'cobol',
#  'c',
#  'lua',
#  'perl']

# %%
PYTHON_CODE = """
def hello_world():
    print("Hello, World!")

# Call the function
hello_world()
"""
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, chunk_size=50, chunk_overlap=0
)
python_docs = python_splitter.create_documents([PYTHON_CODE])
python_docs
# Out:
# [Document(page_content='def hello_world():\n    print("Hello, World!")'),
#  Document(page_content='# Call the function\nhello_world()')]
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
